# %%
import gym
import highway_env
from matplotlib import pyplot as plt
# %matplotlib inline


"""for _ in range(3):
    action = env.action_type.actions_indexes["IDLE"]
    obs, reward, done, truncated, info = env.step(action)
    env.metadata['render_fps'] = 14
    env.render()

plt.imshow(env.render(mode="rgb_array"))
plt.show()"""
# Out:
# 'for _ in range(3):\n    action = env.action_type.actions_indexes["IDLE"]\n    obs, reward, done, truncated, info = env.step(action)\n    env.metadata[\'render_fps\'] = 14\n    env.render()\n\nplt.imshow(env.render(mode="rgb_array"))\nplt.show()'

# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import TD3
from stable_baselines3 import SAC
from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print(f"Saving new best model to {self.save_path}.zip")
                  self.model.save(self.save_path)

        return True

# %%
# Create log dir
log_dir1 = "/tmp/gym/"
os.makedirs(log_dir1, exist_ok=True)

env1 = gym.make('highway-v0')

# Logs will be saved in log_dir/monitor.csv
env1 = Monitor(env1, log_dir1)

env1.configure({"controlled_vehicles": 2})  # Two controlled vehicles
env1.configure({"vehicles_count": 5})  # A single other vehicle, for the sake of visualisation
env1.configure({"collision_reward": 0.6}) 
env1.reset(seed=0)
env1.reset()
# Out:
# /home/rohit/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:31: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (5, 5)
#   logger.warn(
# (array([[ 1.        ,  0.8919273 ,  0.75      ,  0.3125    ,  0.        ],
#         [ 1.        ,  0.11146577, -0.75      , -0.04290927,  0.        ],
#         [ 1.        ,  0.21280849, -0.5       , -0.01288804,  0.        ],
#         [ 1.        ,  0.30696166,  0.        , -0.03807787,  0.        ],
#         [ 1.        ,  0.5119154 , -0.25      ,  0.        ,  0.        ]],
#        dtype=float32),
#  {'speed': 25,
#   'crashed': False,
#   'action': 1,
#   'rewards': {'collision_reward': 0.0,
#    'right_lane_reward': 1.0,
#    'high_speed_reward': 0.5,
#    'on_road_reward': 1.0}})

# %%
import pprint

pprint.pprint(env1.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': 0.6,
#  'controlled_vehicles': 2,
#  'duration': 40,
#  'ego_spacing': 2,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 4,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'vehicles_count': 5,
#  'vehicles_density': 1}

# %%
from stable_baselines3 import DQN

callback1 = SaveOnBestTrainingRewardCallback(check_freq=100, log_dir=log_dir1)

model1 = DQN('MlpPolicy', env1,
              policy_kwargs=dict(net_arch=[256, 256]),
              learning_rate=5e-4,
              buffer_size=15000,
              learning_starts=200,
              batch_size=32,
              gamma=0.8,
              train_freq=1,
              gradient_steps=1,
              target_update_interval=50,
              verbose=1,
              tensorboard_log="highway_dqn/")
model1.learn(int(2e4), callback=callback1)
model1.save("highway_dqn/model1")

model1 = DQN.load("highway_dqn/model1", env=env1)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# 2022-12-12 14:40:58.065707: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-12 14:40:59.136101: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Logging to highway_dqn/DQN_6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.5      |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2        |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 40.5     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4        |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 99       |
# ----------------------------------
# Num timesteps: 100
# Best mean reward: -inf - Last mean reward per episode: 40.51
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 200
# Best mean reward: 40.51 - Last mean reward per episode: 49.01
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 55       |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5        |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 214      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.18     |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 51.6     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4        |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 266      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.743    |
# |    n_updates        | 65       |
# ----------------------------------
# Num timesteps: 300
# Best mean reward: 49.01 - Last mean reward per episode: 51.87
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 66       |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3        |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 370      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.913    |
# |    n_updates        | 169      |
# ----------------------------------
# Num timesteps: 400
# Best mean reward: 51.87 - Last mean reward per episode: 65.95
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 500
# Best mean reward: 65.95 - Last mean reward per episode: 81.38
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 85.1     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2        |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 527      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.66     |
# |    n_updates        | 326      |
# ----------------------------------
# Num timesteps: 600
# Best mean reward: 81.38 - Last mean reward per episode: 85.87
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2        |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 605      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.08     |
# |    n_updates        | 404      |
# ----------------------------------
# Num timesteps: 700
# Best mean reward: 85.87 - Last mean reward per episode: 87.23
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 90.8     |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2        |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 711      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.54     |
# |    n_updates        | 510      |
# ----------------------------------
# Num timesteps: 800
# Best mean reward: 87.23 - Last mean reward per episode: 92.38
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 98.4     |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2        |
# |    time_elapsed     | 326      |
# |    total_timesteps  | 844      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.31     |
# |    n_updates        | 643      |
# ----------------------------------
# Num timesteps: 900
# Best mean reward: 92.38 - Last mean reward per episode: 101.06
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 1000
# Best mean reward: 101.06 - Last mean reward per episode: 106.69
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2        |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 1004     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.81     |
# |    n_updates        | 803      |
# ----------------------------------
# Num timesteps: 1100
# Best mean reward: 106.69 - Last mean reward per episode: 113.78
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.5     |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2        |
# |    time_elapsed     | 472      |
# |    total_timesteps  | 1164     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.15     |
# |    n_updates        | 963      |
# ----------------------------------
# Num timesteps: 1200
# Best mean reward: 113.78 - Last mean reward per episode: 117.57
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.409    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2        |
# |    time_elapsed     | 505      |
# |    total_timesteps  | 1244     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.89     |
# |    n_updates        | 1043     |
# ----------------------------------
# Num timesteps: 1300
# Best mean reward: 117.57 - Last mean reward per episode: 119.96
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 1400
# Best mean reward: 119.96 - Last mean reward per episode: 124.18
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27       |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2        |
# |    time_elapsed     | 582      |
# |    total_timesteps  | 1404     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.05     |
# |    n_updates        | 1203     |
# ----------------------------------
# Num timesteps: 1500
# Best mean reward: 124.18 - Last mean reward per episode: 129.50
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.9     |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.257    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2        |
# |    time_elapsed     | 655      |
# |    total_timesteps  | 1564     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.879    |
# |    n_updates        | 1363     |
# ----------------------------------
# Num timesteps: 1600
# Best mean reward: 129.50 - Last mean reward per episode: 133.06
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 1700
# Best mean reward: 133.06 - Last mean reward per episode: 138.14
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.181    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2        |
# |    time_elapsed     | 733      |
# |    total_timesteps  | 1724     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.977    |
# |    n_updates        | 1523     |
# ----------------------------------
# Num timesteps: 1800
# Best mean reward: 138.14 - Last mean reward per episode: 141.63
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.4     |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.138    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2        |
# |    time_elapsed     | 776      |
# |    total_timesteps  | 1815     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 1614     |
# ----------------------------------
# Num timesteps: 1900
# Best mean reward: 141.63 - Last mean reward per episode: 138.97
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.6     |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.0757   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2        |
# |    time_elapsed     | 841      |
# |    total_timesteps  | 1946     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.182    |
# |    n_updates        | 1745     |
# ----------------------------------
# Num timesteps: 2000
# Best mean reward: 141.63 - Last mean reward per episode: 143.17
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2        |
# |    time_elapsed     | 908      |
# |    total_timesteps  | 2078     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0516   |
# |    n_updates        | 1877     |
# ----------------------------------
# Num timesteps: 2100
# Best mean reward: 143.17 - Last mean reward per episode: 144.65
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2200
# Best mean reward: 144.65 - Last mean reward per episode: 148.35
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2        |
# |    time_elapsed     | 990      |
# |    total_timesteps  | 2238     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.12     |
# |    n_updates        | 2037     |
# ----------------------------------
# Num timesteps: 2300
# Best mean reward: 148.35 - Last mean reward per episode: 150.69
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30       |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2        |
# |    time_elapsed     | 1067     |
# |    total_timesteps  | 2398     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.789    |
# |    n_updates        | 2197     |
# ----------------------------------
# Num timesteps: 2400
# Best mean reward: 150.69 - Last mean reward per episode: 153.95
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2500
# Best mean reward: 153.95 - Last mean reward per episode: 154.23
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30       |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2        |
# |    time_elapsed     | 1125     |
# |    total_timesteps  | 2521     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.171    |
# |    n_updates        | 2320     |
# ----------------------------------
# Num timesteps: 2600
# Best mean reward: 154.23 - Last mean reward per episode: 155.14
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2        |
# |    time_elapsed     | 1190     |
# |    total_timesteps  | 2653     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1        |
# |    n_updates        | 2452     |
# ----------------------------------
# Num timesteps: 2700
# Best mean reward: 155.14 - Last mean reward per episode: 156.77
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.4     |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2        |
# |    time_elapsed     | 1264     |
# |    total_timesteps  | 2797     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.159    |
# |    n_updates        | 2596     |
# ----------------------------------
# Num timesteps: 2800
# Best mean reward: 156.77 - Last mean reward per episode: 159.38
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2900
# Best mean reward: 159.38 - Last mean reward per episode: 161.00
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.8     |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2        |
# |    time_elapsed     | 1342     |
# |    total_timesteps  | 2953     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.149    |
# |    n_updates        | 2752     |
# ----------------------------------
# Num timesteps: 3000
# Best mean reward: 161.00 - Last mean reward per episode: 161.49
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.9     |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2        |
# |    time_elapsed     | 1406     |
# |    total_timesteps  | 3089     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.76     |
# |    n_updates        | 2888     |
# ----------------------------------
# Num timesteps: 3100
# Best mean reward: 161.49 - Last mean reward per episode: 163.77
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3200
# Best mean reward: 163.77 - Last mean reward per episode: 168.16
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.9     |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2        |
# |    time_elapsed     | 1467     |
# |    total_timesteps  | 3219     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.825    |
# |    n_updates        | 3018     |
# ----------------------------------
# Num timesteps: 3300
# Best mean reward: 168.16 - Last mean reward per episode: 174.67
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.8     |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2        |
# |    time_elapsed     | 1548     |
# |    total_timesteps  | 3379     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0839   |
# |    n_updates        | 3178     |
# ----------------------------------
# Num timesteps: 3400
# Best mean reward: 174.67 - Last mean reward per episode: 177.62
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3500
# Best mean reward: 177.62 - Last mean reward per episode: 182.62
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.2     |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2        |
# |    time_elapsed     | 1561     |
# |    total_timesteps  | 3539     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.917    |
# |    n_updates        | 3338     |
# ----------------------------------
# Num timesteps: 3600
# Best mean reward: 182.62 - Last mean reward per episode: 185.86
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2        |
# |    time_elapsed     | 1573     |
# |    total_timesteps  | 3690     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0335   |
# |    n_updates        | 3489     |
# ----------------------------------
# Num timesteps: 3700
# Best mean reward: 185.86 - Last mean reward per episode: 191.05
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3800
# Best mean reward: 191.05 - Last mean reward per episode: 194.72
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.8     |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2        |
# |    time_elapsed     | 1592     |
# |    total_timesteps  | 3850     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.968    |
# |    n_updates        | 3649     |
# ----------------------------------
# Num timesteps: 3900
# Best mean reward: 194.72 - Last mean reward per episode: 194.92
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.6     |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2        |
# |    time_elapsed     | 1604     |
# |    total_timesteps  | 3985     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.06     |
# |    n_updates        | 3784     |
# ----------------------------------
# Num timesteps: 4000
# Best mean reward: 194.92 - Last mean reward per episode: 196.27
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4100
# Best mean reward: 196.27 - Last mean reward per episode: 198.70
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.4     |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2        |
# |    time_elapsed     | 1620     |
# |    total_timesteps  | 4145     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0347   |
# |    n_updates        | 3944     |
# ----------------------------------
# Num timesteps: 4200
# Best mean reward: 198.70 - Last mean reward per episode: 204.57
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4300
# Best mean reward: 204.57 - Last mean reward per episode: 206.22
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.9     |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2        |
# |    time_elapsed     | 1645     |
# |    total_timesteps  | 4305     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0242   |
# |    n_updates        | 4104     |
# ----------------------------------
# Num timesteps: 4400
# Best mean reward: 206.22 - Last mean reward per episode: 208.90
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2        |
# |    time_elapsed     | 1667     |
# |    total_timesteps  | 4465     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0466   |
# |    n_updates        | 4264     |
# ----------------------------------
# Num timesteps: 4500
# Best mean reward: 208.90 - Last mean reward per episode: 209.59
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4600
# Best mean reward: 209.59 - Last mean reward per episode: 210.52
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2        |
# |    time_elapsed     | 1690     |
# |    total_timesteps  | 4625     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0196   |
# |    n_updates        | 4424     |
# ----------------------------------
# Num timesteps: 4700
# Best mean reward: 210.52 - Last mean reward per episode: 211.15
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2        |
# |    time_elapsed     | 1703     |
# |    total_timesteps  | 4785     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0436   |
# |    n_updates        | 4584     |
# ----------------------------------
# Num timesteps: 4800
# Best mean reward: 211.15 - Last mean reward per episode: 211.72
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4900
# Best mean reward: 211.72 - Last mean reward per episode: 215.98
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2        |
# |    time_elapsed     | 1719     |
# |    total_timesteps  | 4930     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0857   |
# |    n_updates        | 4729     |
# ----------------------------------
# Num timesteps: 5000
# Best mean reward: 215.98 - Last mean reward per episode: 216.14
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2        |
# |    time_elapsed     | 1741     |
# |    total_timesteps  | 5090     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0496   |
# |    n_updates        | 4889     |
# ----------------------------------
# Num timesteps: 5100
# Best mean reward: 216.14 - Last mean reward per episode: 216.50
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5200
# Best mean reward: 216.50 - Last mean reward per episode: 216.89
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2        |
# |    time_elapsed     | 1768     |
# |    total_timesteps  | 5250     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0712   |
# |    n_updates        | 5049     |
# ----------------------------------
# Num timesteps: 5300
# Best mean reward: 216.89 - Last mean reward per episode: 215.27
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.6     |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3        |
# |    time_elapsed     | 1785     |
# |    total_timesteps  | 5380     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0273   |
# |    n_updates        | 5179     |
# ----------------------------------
# Num timesteps: 5400
# Best mean reward: 216.89 - Last mean reward per episode: 215.41
# Num timesteps: 5500
# Best mean reward: 216.89 - Last mean reward per episode: 217.91
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 3        |
# |    time_elapsed     | 1808     |
# |    total_timesteps  | 5518     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0204   |
# |    n_updates        | 5317     |
# ----------------------------------
# Num timesteps: 5600
# Best mean reward: 217.91 - Last mean reward per episode: 219.88
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.3     |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 3        |
# |    time_elapsed     | 1819     |
# |    total_timesteps  | 5672     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0264   |
# |    n_updates        | 5471     |
# ----------------------------------
# Num timesteps: 5700
# Best mean reward: 219.88 - Last mean reward per episode: 219.89
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5800
# Best mean reward: 219.89 - Last mean reward per episode: 219.89
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.5     |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3        |
# |    time_elapsed     | 1836     |
# |    total_timesteps  | 5832     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0467   |
# |    n_updates        | 5631     |
# ----------------------------------
# Num timesteps: 5900
# Best mean reward: 219.89 - Last mean reward per episode: 220.72
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3        |
# |    time_elapsed     | 1854     |
# |    total_timesteps  | 5977     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.761    |
# |    n_updates        | 5776     |
# ----------------------------------
# Num timesteps: 6000
# Best mean reward: 220.72 - Last mean reward per episode: 220.75
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6100
# Best mean reward: 220.75 - Last mean reward per episode: 220.73
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3        |
# |    time_elapsed     | 1878     |
# |    total_timesteps  | 6137     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0178   |
# |    n_updates        | 5936     |
# ----------------------------------
# Num timesteps: 6200
# Best mean reward: 220.75 - Last mean reward per episode: 220.72
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.8     |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3        |
# |    time_elapsed     | 1897     |
# |    total_timesteps  | 6297     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.948    |
# |    n_updates        | 6096     |
# ----------------------------------
# Num timesteps: 6300
# Best mean reward: 220.75 - Last mean reward per episode: 223.00
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6400
# Best mean reward: 223.00 - Last mean reward per episode: 223.08
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.8     |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 3        |
# |    time_elapsed     | 1914     |
# |    total_timesteps  | 6430     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0873   |
# |    n_updates        | 6229     |
# ----------------------------------
# Num timesteps: 6500
# Best mean reward: 223.08 - Last mean reward per episode: 224.15
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.9     |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 3        |
# |    time_elapsed     | 1938     |
# |    total_timesteps  | 6590     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0223   |
# |    n_updates        | 6389     |
# ----------------------------------
# Num timesteps: 6600
# Best mean reward: 224.15 - Last mean reward per episode: 224.17
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6700
# Best mean reward: 224.17 - Last mean reward per episode: 222.41
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.7     |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 3        |
# |    time_elapsed     | 1954     |
# |    total_timesteps  | 6721     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0281   |
# |    n_updates        | 6520     |
# ----------------------------------
# Num timesteps: 6800
# Best mean reward: 224.17 - Last mean reward per episode: 222.84
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.7     |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 3        |
# |    time_elapsed     | 1966     |
# |    total_timesteps  | 6858     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0256   |
# |    n_updates        | 6657     |
# ----------------------------------
# Num timesteps: 6900
# Best mean reward: 224.17 - Last mean reward per episode: 224.66
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7000
# Best mean reward: 224.66 - Last mean reward per episode: 224.70
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38       |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 3        |
# |    time_elapsed     | 1985     |
# |    total_timesteps  | 7018     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0554   |
# |    n_updates        | 6817     |
# ----------------------------------
# Num timesteps: 7100
# Best mean reward: 224.70 - Last mean reward per episode: 224.77
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38       |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 3        |
# |    time_elapsed     | 2003     |
# |    total_timesteps  | 7178     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.915    |
# |    n_updates        | 6977     |
# ----------------------------------
# Num timesteps: 7200
# Best mean reward: 224.77 - Last mean reward per episode: 224.72
# Num timesteps: 7300
# Best mean reward: 224.77 - Last mean reward per episode: 222.94
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.7     |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 3        |
# |    time_elapsed     | 2019     |
# |    total_timesteps  | 7310     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.02     |
# |    n_updates        | 7109     |
# ----------------------------------
# Num timesteps: 7400
# Best mean reward: 224.77 - Last mean reward per episode: 222.02
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.7     |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 3        |
# |    time_elapsed     | 2035     |
# |    total_timesteps  | 7456     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0287   |
# |    n_updates        | 7255     |
# ----------------------------------
# Num timesteps: 7500
# Best mean reward: 224.77 - Last mean reward per episode: 222.03
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3        |
# |    time_elapsed     | 2051     |
# |    total_timesteps  | 7561     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00812  |
# |    n_updates        | 7360     |
# ----------------------------------
# Num timesteps: 7600
# Best mean reward: 224.77 - Last mean reward per episode: 219.50
# Num timesteps: 7700
# Best mean reward: 224.77 - Last mean reward per episode: 219.58
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3        |
# |    time_elapsed     | 2075     |
# |    total_timesteps  | 7701     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0398   |
# |    n_updates        | 7500     |
# ----------------------------------
# Num timesteps: 7800
# Best mean reward: 224.77 - Last mean reward per episode: 219.56
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3        |
# |    time_elapsed     | 2117     |
# |    total_timesteps  | 7861     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0209   |
# |    n_updates        | 7660     |
# ----------------------------------
# Num timesteps: 7900
# Best mean reward: 224.77 - Last mean reward per episode: 219.59
# Num timesteps: 8000
# Best mean reward: 224.77 - Last mean reward per episode: 219.59
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3        |
# |    time_elapsed     | 2134     |
# |    total_timesteps  | 8021     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0602   |
# |    n_updates        | 7820     |
# ----------------------------------
# Num timesteps: 8100
# Best mean reward: 224.77 - Last mean reward per episode: 219.70
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3        |
# |    time_elapsed     | 2147     |
# |    total_timesteps  | 8181     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.027    |
# |    n_updates        | 7980     |
# ----------------------------------
# Num timesteps: 8200
# Best mean reward: 224.77 - Last mean reward per episode: 219.68
# Num timesteps: 8300
# Best mean reward: 224.77 - Last mean reward per episode: 217.28
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3        |
# |    time_elapsed     | 2165     |
# |    total_timesteps  | 8303     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0418   |
# |    n_updates        | 8102     |
# ----------------------------------
# Num timesteps: 8400
# Best mean reward: 224.77 - Last mean reward per episode: 217.28
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3        |
# |    time_elapsed     | 2205     |
# |    total_timesteps  | 8463     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0843   |
# |    n_updates        | 8262     |
# ----------------------------------
# Num timesteps: 8500
# Best mean reward: 224.77 - Last mean reward per episode: 217.29
# Num timesteps: 8600
# Best mean reward: 224.77 - Last mean reward per episode: 218.20
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3        |
# |    time_elapsed     | 2221     |
# |    total_timesteps  | 8623     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.029    |
# |    n_updates        | 8422     |
# ----------------------------------
# Num timesteps: 8700
# Best mean reward: 224.77 - Last mean reward per episode: 217.91
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3        |
# |    time_elapsed     | 2234     |
# |    total_timesteps  | 8779     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.861    |
# |    n_updates        | 8578     |
# ----------------------------------
# Num timesteps: 8800
# Best mean reward: 224.77 - Last mean reward per episode: 217.91
# Num timesteps: 8900
# Best mean reward: 224.77 - Last mean reward per episode: 217.87
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3        |
# |    time_elapsed     | 2249     |
# |    total_timesteps  | 8939     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0192   |
# |    n_updates        | 8738     |
# ----------------------------------
# Num timesteps: 9000
# Best mean reward: 224.77 - Last mean reward per episode: 219.75
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 4        |
# |    time_elapsed     | 2267     |
# |    total_timesteps  | 9099     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0439   |
# |    n_updates        | 8898     |
# ----------------------------------
# Num timesteps: 9100
# Best mean reward: 224.77 - Last mean reward per episode: 219.65
# Num timesteps: 9200
# Best mean reward: 224.77 - Last mean reward per episode: 219.69
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 4        |
# |    time_elapsed     | 2298     |
# |    total_timesteps  | 9259     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0931   |
# |    n_updates        | 9058     |
# ----------------------------------
# Num timesteps: 9300
# Best mean reward: 224.77 - Last mean reward per episode: 221.11
# Num timesteps: 9400
# Best mean reward: 224.77 - Last mean reward per episode: 221.57
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.5     |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3        |
# |    time_elapsed     | 2372     |
# |    total_timesteps  | 9419     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0311   |
# |    n_updates        | 9218     |
# ----------------------------------
# Num timesteps: 9500
# Best mean reward: 224.77 - Last mean reward per episode: 220.87
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3        |
# |    time_elapsed     | 2440     |
# |    total_timesteps  | 9556     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.953    |
# |    n_updates        | 9355     |
# ----------------------------------
# Num timesteps: 9600
# Best mean reward: 224.77 - Last mean reward per episode: 219.87
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3        |
# |    time_elapsed     | 2498     |
# |    total_timesteps  | 9698     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0268   |
# |    n_updates        | 9497     |
# ----------------------------------
# Num timesteps: 9700
# Best mean reward: 224.77 - Last mean reward per episode: 219.77
# Num timesteps: 9800
# ...
# Best mean reward: 228.33 - Last mean reward per episode: 225.94
# Num timesteps: 16400
# Best mean reward: 228.33 - Last mean reward per episode: 225.96
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.2     |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 2        |
# |    time_elapsed     | 5690     |
# |    total_timesteps  | 16400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00225  |
# |    n_updates        | 16199    |
# ----------------------------------
# Num timesteps: 16500
# Best mean reward: 228.33 - Last mean reward per episode: 225.23
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.1     |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1        |
# |    time_elapsed     | 8405     |
# |    total_timesteps  | 16539    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.847    |
# |    n_updates        | 16338    |
# ----------------------------------
# Num timesteps: 16600
# Best mean reward: 228.33 - Last mean reward per episode: 225.23
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.1     |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1        |
# |    time_elapsed     | 8467     |
# |    total_timesteps  | 16699    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0125   |
# |    n_updates        | 16498    |
# ----------------------------------
# Num timesteps: 16700
# Best mean reward: 228.33 - Last mean reward per episode: 225.22
# Num timesteps: 16800
# Best mean reward: 228.33 - Last mean reward per episode: 223.70
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.8     |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1        |
# |    time_elapsed     | 8526     |
# |    total_timesteps  | 16835    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00859  |
# |    n_updates        | 16634    |
# ----------------------------------
# Num timesteps: 16900
# Best mean reward: 228.33 - Last mean reward per episode: 223.70
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.8     |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1        |
# |    time_elapsed     | 8597     |
# |    total_timesteps  | 16995    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0128   |
# |    n_updates        | 16794    |
# ----------------------------------
# Num timesteps: 17000
# Best mean reward: 228.33 - Last mean reward per episode: 223.67
# Num timesteps: 17100
# Best mean reward: 228.33 - Last mean reward per episode: 225.23
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.1     |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1        |
# |    time_elapsed     | 8675     |
# |    total_timesteps  | 17155    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0176   |
# |    n_updates        | 16954    |
# ----------------------------------
# Num timesteps: 17200
# Best mean reward: 228.33 - Last mean reward per episode: 225.62
# Num timesteps: 17300
# Best mean reward: 228.33 - Last mean reward per episode: 227.29
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.4     |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 1        |
# |    time_elapsed     | 8749     |
# |    total_timesteps  | 17315    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0111   |
# |    n_updates        | 17114    |
# ----------------------------------
# Num timesteps: 17400
# Best mean reward: 228.33 - Last mean reward per episode: 227.38
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.4     |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1        |
# |    time_elapsed     | 8831     |
# |    total_timesteps  | 17475    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00982  |
# |    n_updates        | 17274    |
# ----------------------------------
# Num timesteps: 17500
# Best mean reward: 228.33 - Last mean reward per episode: 227.39
# Num timesteps: 17600
# Best mean reward: 228.33 - Last mean reward per episode: 227.38
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.4     |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 1        |
# |    time_elapsed     | 8915     |
# |    total_timesteps  | 17635    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0105   |
# |    n_updates        | 17434    |
# ----------------------------------
# Num timesteps: 17700
# Best mean reward: 228.33 - Last mean reward per episode: 227.42
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.4     |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 1        |
# |    time_elapsed     | 8990     |
# |    total_timesteps  | 17795    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00962  |
# |    n_updates        | 17594    |
# ----------------------------------
# Num timesteps: 17800
# Best mean reward: 228.33 - Last mean reward per episode: 227.42
# Num timesteps: 17900
# Best mean reward: 228.33 - Last mean reward per episode: 227.57
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.4     |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 1        |
# |    time_elapsed     | 9051     |
# |    total_timesteps  | 17930    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.875    |
# |    n_updates        | 17729    |
# ----------------------------------
# Num timesteps: 18000
# Best mean reward: 228.33 - Last mean reward per episode: 227.58
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.4     |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 1        |
# |    time_elapsed     | 9126     |
# |    total_timesteps  | 18090    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0177   |
# |    n_updates        | 17889    |
# ----------------------------------
# Num timesteps: 18100
# Best mean reward: 228.33 - Last mean reward per episode: 227.57
# Num timesteps: 18200
# Best mean reward: 228.33 - Last mean reward per episode: 227.60
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.3     |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1        |
# |    time_elapsed     | 9197     |
# |    total_timesteps  | 18236    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00634  |
# |    n_updates        | 18035    |
# ----------------------------------
# Num timesteps: 18300
# Best mean reward: 228.33 - Last mean reward per episode: 228.85
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 1        |
# |    time_elapsed     | 9279     |
# |    total_timesteps  | 18396    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00781  |
# |    n_updates        | 18195    |
# ----------------------------------
# Num timesteps: 18400
# Best mean reward: 228.85 - Last mean reward per episode: 229.88
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 18500
# Best mean reward: 229.88 - Last mean reward per episode: 230.70
# Saving new best model to /tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39       |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 1        |
# |    time_elapsed     | 9360     |
# |    total_timesteps  | 18556    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0103   |
# |    n_updates        | 18355    |
# ----------------------------------
# Num timesteps: 18600
# Best mean reward: 230.70 - Last mean reward per episode: 230.68
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 1        |
# |    time_elapsed     | 9427     |
# |    total_timesteps  | 18695    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0026   |
# |    n_updates        | 18494    |
# ----------------------------------
# Num timesteps: 18700
# Best mean reward: 230.70 - Last mean reward per episode: 229.34
# Num timesteps: 18800
# Best mean reward: 230.70 - Last mean reward per episode: 229.36
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 1        |
# |    time_elapsed     | 9504     |
# |    total_timesteps  | 18855    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0251   |
# |    n_updates        | 18654    |
# ----------------------------------
# Num timesteps: 18900
# Best mean reward: 230.70 - Last mean reward per episode: 229.32
# Num timesteps: 19000
# Best mean reward: 230.70 - Last mean reward per episode: 229.32
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1        |
# |    time_elapsed     | 9585     |
# |    total_timesteps  | 19015    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0036   |
# |    n_updates        | 18814    |
# ----------------------------------
# Num timesteps: 19100
# Best mean reward: 230.70 - Last mean reward per episode: 229.35
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 1        |
# |    time_elapsed     | 9659     |
# |    total_timesteps  | 19175    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0297   |
# |    n_updates        | 18974    |
# ----------------------------------
# Num timesteps: 19200
# Best mean reward: 230.70 - Last mean reward per episode: 229.30
# Num timesteps: 19300
# Best mean reward: 230.70 - Last mean reward per episode: 229.28
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 1        |
# |    time_elapsed     | 9743     |
# |    total_timesteps  | 19335    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00761  |
# |    n_updates        | 19134    |
# ----------------------------------
# Num timesteps: 19400
# Best mean reward: 230.70 - Last mean reward per episode: 229.27
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 1        |
# |    time_elapsed     | 9819     |
# |    total_timesteps  | 19495    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0114   |
# |    n_updates        | 19294    |
# ----------------------------------
# Num timesteps: 19500
# Best mean reward: 230.70 - Last mean reward per episode: 229.30
# Num timesteps: 19600
# Best mean reward: 230.70 - Last mean reward per episode: 229.25
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 1        |
# |    time_elapsed     | 9893     |
# |    total_timesteps  | 19655    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0144   |
# |    n_updates        | 19454    |
# ----------------------------------
# Num timesteps: 19700
# Best mean reward: 230.70 - Last mean reward per episode: 229.19
# Num timesteps: 19800
# Best mean reward: 230.70 - Last mean reward per episode: 229.25
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 1        |
# |    time_elapsed     | 9969     |
# |    total_timesteps  | 19815    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0142   |
# |    n_updates        | 19614    |
# ----------------------------------
# Num timesteps: 19900
# Best mean reward: 230.70 - Last mean reward per episode: 229.33
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.9     |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 1        |
# |    time_elapsed     | 10046    |
# |    total_timesteps  | 19968    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0372   |
# |    n_updates        | 19767    |
# ----------------------------------
# Num timesteps: 20000
# Best mean reward: 230.70 - Last mean reward per episode: 230.11
# Wrapping the env in a DummyVecEnv.

# %%
from stable_baselines3.common import results_plotter

# Helper from the library
results_plotter.plot_results([log_dir1], 1e5, results_plotter.X_TIMESTEPS, "DQN Highway Env")

# %%
def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), 'timesteps')
    y = moving_average(y, window=50)
    # Truncate x
    x = x[len(x) - len(y):]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title + " Smoothed")
    plt.show()

# %%
plot_results(log_dir1)

# %%
env2 = gym.make('highway-v0')

env2.configure({"controlled_vehicles": 5})  # Two controlled vehicles
env2.configure({"vehicles_count": 0})  # A single other vehicle, for the sake of visualisation
env2.configure({"collision_reward": 1}) 
env2.reset(seed=0)
env2.reset()
# Out:
# /home/rohit/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:31: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (5, 5)
#   logger.warn(
# (array([[ 1.        ,  0.9028463 ,  0.25      ,  0.3125    ,  0.        ],
#         [ 1.        ,  0.20898543, -0.25      ,  0.        ,  0.        ],
#         [ 1.        ,  0.4309162 ,  0.25      ,  0.        ,  0.        ],
#         [ 1.        ,  0.6347424 ,  0.        ,  0.        ,  0.        ],
#         [ 1.        ,  0.8557819 ,  0.        ,  0.        ,  0.        ]],
#        dtype=float32),
#  {'speed': 25,
#   'crashed': False,
#   'action': 4,
#   'rewards': {'collision_reward': 0.0,
#    'right_lane_reward': 0.3333333333333333,
#    'high_speed_reward': 0.5,
#    'on_road_reward': 1.0}})

# %%
model2 = DQN('MlpPolicy', env2,
              policy_kwargs=dict(net_arch=[256, 256]),
              learning_rate=5e-4,
              buffer_size=15000,
              learning_starts=200,
              batch_size=32,
              gamma=0.8,
              train_freq=1,
              gradient_steps=1,
              target_update_interval=50,
              verbose=1,
              tensorboard_log="highway_dqn/")
model2.learn(int(2e4))
model2.save("highway_dqn/model2")

model2 = DQN.load("highway_dqn/model2", env=env2)

# %%
env3 = gym.make('highway-v0')

env3.configure({"controlled_vehicles": 2})  # Two controlled vehicles
env3.configure({"vehicles_count": 4})  # A single other vehicle, for the sake of visualisation
env3.configure({"collision_reward": 0.5}) 
env3.configure({

  "observation": {
    "type": "MultiAgentObservation",
    "observation_config": {
      "type": "Kinematics",
    }
  },
  "action": {
    "type": "MultiAgentAction",
    "action_config": {
      "type": "DiscreteMetaAction",
    }
  }
})
env3.reset()

"""
_, (ax1, ax2) = plt.subplots(nrows=2)
ax1.imshow(env2.render(mode="rgb_array"))
ax1.set_title("Initial state")

# Make the first vehicle change to the left lane, and the second one to the right
action_1, action_2 = 0, 2  # See highway_env.envs.common.action.DiscreteMetaAction.ACTIONS_ALL
env2.step((action_1, action_2))

ax2.imshow(env2.render(mode="rgb_array"))
ax2.set_title("After sending actions to each vehicle")
plt.show()"""
# Out:
# /home/rohit/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:31: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (5, 5)
#   logger.warn(
# '\n_, (ax1, ax2) = plt.subplots(nrows=2)\nax1.imshow(env2.render(mode="rgb_array"))\nax1.set_title("Initial state")\n\n# Make the first vehicle change to the left lane, and the second one to the right\naction_1, action_2 = 0, 2  # See highway_env.envs.common.action.DiscreteMetaAction.ACTIONS_ALL\nenv2.step((action_1, action_2))\n\nax2.imshow(env2.render(mode="rgb_array"))\nax2.set_title("After sending actions to each vehicle")\nplt.show()'

# %%
from stable_baselines3 import DQN

model1 = DQN.load("highway_dqn/model1",env=env1)
model2 = DQN.load("highway_dqn/model2",env=env2)
while True:
  vec_env1=model1.get_env()
  done = truncated = False
  obs1 = vec_env1.reset()

  vec_env2=model2.get_env()
  done = truncated = False
  obs2 = vec_env2.reset()

  #print(info)
  while not (done or truncated):
    action1, _states1 = model1.predict(obs1, deterministic=True)
    action2, _states2 = model2.predict(obs2, deterministic=True)

    env3.metadata['render_fps'] = 14
    env3.step((action1[0], action2[0]))
    env3.render()


    
    """_, (ax1, ax2) = plt.subplots(nrows=2)
    ax1.imshow(env3.render(mode="rgb_array"))
    ax1.set_title("Initial state")
    print(action1,action2)
    # Make the first vehicle change to the left lane, and the second one to the right
    #action_1, action_2 = 0, 2  # See highway_env.envs.common.action.DiscreteMetaAction.ACTIONS_ALL
    env3.step((action1[0], action2[0]))

    ax2.imshow(env3.render(mode="rgb_array"))
    ax2.set_title("After sending actions to each vehicle")
    plt.show()"""
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:259: UserWarning: WARN: The reward is an inf value.
#   logger.warn("The reward is an inf value.")
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/rohit/.local/lib/python3.10/site-packages/highway_env/utils.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 20
#      17 action2, _states2 = model2.predict(obs2, deterministic=True)
#      19 env3.metadata['render_fps'] = 14
# ---> 20 env3.step((action1[0], action2[0]))
#      21 env3.render()
#      25 """_, (ax1, ax2) = plt.subplots(nrows=2)
#      26 ax1.imshow(env3.render(mode="rgb_array"))
#      27 ax1.set_title("Initial state")
#    (...)
#      34 ax2.set_title("After sending actions to each vehicle")
#      35 plt.show()"""
#
# File ~/.local/lib/python3.10/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/gym/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/highway_env/envs/common/abstract.py:229, in AbstractEnv.step(self, action)
#     226 self.time += 1 / self.config["policy_frequency"]
#     227 self._simulate(action)
# --> 229 obs = self.observation_type.observe()
#     230 reward = self._reward(action)
#     231 terminated = self._is_terminated()
#
# File ~/.local/lib/python3.10/site-packages/highway_env/envs/common/observation.py:207, in KinematicObservation.observe(self)
#     204     return np.zeros(self.space().shape)
#     206 # Add ego-vehicle
# --> 207 df = pd.DataFrame.from_records([self.observer_vehicle.to_dict()])[self.features]
#     208 # Add nearby traffic
#     209 close_vehicles = self.env.road.close_vehicles_to(self.observer_vehicle,
#     210                                                  self.env.PERCEPTION_DISTANCE,
#     211                                                  count=self.vehicles_count - 1,
#     212                                                  see_behind=self.see_behind,
#     213                                                  sort=self.order == "sorted")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3817, in DataFrame.__getitem__(self, key)
#    3814 if getattr(indexer, "dtype", None) == bool:
#    3815     indexer = np.where(indexer)[0]
# -> 3817 data = self._take_with_is_copy(indexer, axis=1)
#    3819 if is_single_key:
#    3820     # What does looking for a single key in a non-unique index return?
#    3821     # The behavior is inconsistent. It returns a Series, except when
#    3822     # - the key itself is repeated (test on data.shape, #9519), or
#    3823     # - we have a MultiIndex on columns (test on self.columns, #21309)
#    3824     if data.shape[1] == 1 and not isinstance(self.columns, MultiIndex):
#    3825         # GH#26490 using data[key] can cause RecursionError
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3902, in NDFrame._take_with_is_copy(self, indices, axis)
#    3894 def _take_with_is_copy(self: NDFrameT, indices, axis=0) -> NDFrameT:
#    3895     """
#    3896     Internal version of the `take` method that sets the `_is_copy`
#    3897     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3900     See the docstring of `take` for full explanation of the parameters.
#    3901     """
# -> 3902     result = self._take(indices=indices, axis=axis)
#    3903     # Maybe set copy if we didn't actually change the index.
#    3904     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3886, in NDFrame._take(self, indices, axis, convert_indices)
#    3879 """
#    3880 Internal version of the `take` allowing specification of additional args.
#    3881
#    3882 See the docstring of `take` for full explanation of the parameters.
#    3883 """
#    3884 self._consolidate_inplace()
# -> 3886 new_data = self._mgr.take(
#    3887     indices,
#    3888     axis=self._get_block_manager_axis(axis),
#    3889     verify=True,
#    3890     convert_indices=convert_indices,
#    3891 )
#    3892 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:980, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     977     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     979 new_labels = self.axes[axis].take(indexer)
# --> 980 return self.reindex_indexer(
#     981     new_axis=new_labels,
#     982     indexer=indexer,
#     983     axis=axis,
#     984     allow_dups=True,
#     985     copy=None,
#     986 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:745, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     742     raise IndexError("Requested axis not found in manager")
#     744 if axis == 0:
# --> 745     new_blocks, new_refs = self._slice_take_blocks_ax0(
#     746         indexer,
#     747         fill_value=fill_value,
#     748         only_slice=only_slice,
#     749         use_na_proxy=use_na_proxy,
#     750     )
#     751     parent = None if com.all_none(*new_refs) else self
#     752 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:914, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     912         refs.append(weakref.ref(blk))
#     913 else:
# --> 914     nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     915     blocks.append(nb)
#     916     refs.append(None)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:880, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     877     allow_fill = True
#     879 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 880 new_values = algos.take_nd(
#     881     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     882 )
#     884 # Called from three places in managers, all of which satisfy
#     885 #  this assertion
#     886 assert not (axis == 0 and new_mgr_locs is None)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# KeyboardInterrupt:

# %%
from stable_baselines3 import DQN

model1 = DQN.load("highway_dqn/model1",env=env1)
model2 = DQN.load("highway_dqn/model2",env=env2)
while True:
  vec_env1=model1.get_env()
  done = truncated = False
  obs1 = vec_env1.reset()

  vec_env2=model2.get_env()
  done = truncated = False
  obs2 = vec_env2.reset()

  vec_env3=model1.get_env()
  done = truncated = False
  obs3 = vec_env3.reset()


  #print(info)
  while not (done or truncated):
    action1, _states1 = model1.predict(obs1, deterministic=True)
    action2, _states2 = model2.predict(obs2, deterministic=True)

    action = tuple(model1.predict(obs1, deterministic=True))
    obs1, reward1, done1, info1= vec_env1.step(action1)
    obs2, reward2, done2, info2 = vec_env2.step(action2)
    vec_env3.metadata['render_fps'] = 14
    vec_env1.step((action1[0], action2[0]))
    #vec_env3.render()
    #vec_env1.render()
    vec_env1.render()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 26
#      24 action = tuple(model1.predict(obs1, deterministic=True))
#      25 obs1, reward1, done1, info1= vec_env1.step(action1)
# ---> 26 obs2, reward2, done2, info2 = vec_env2.step(action2)
#      27 vec_env3.metadata['render_fps'] = 14
#      28 vec_env1.step((action1[0], action2[0]))
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:55, in DummyVecEnv.step_wait(self)
#      52 def step_wait(self) -> VecEnvStepReturn:
#      53     # Avoid circular imports
#      54     for env_idx in range(self.num_envs):
# ---> 55         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      56             self.actions[env_idx]
#      57         )
#      58         # convert to SB3 VecEnv api
#      59         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if terminated or truncated:
#
# File ~/.local/lib/python3.10/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/gym/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/highway_env/envs/common/abstract.py:227, in AbstractEnv.step(self, action)
#     224     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     226 self.time += 1 / self.config["policy_frequency"]
# --> 227 self._simulate(action)
#     229 obs = self.observation_type.observe()
#     230 reward = self._reward(action)
#
# File ~/.local/lib/python3.10/site-packages/highway_env/envs/common/abstract.py:247, in AbstractEnv._simulate(self, action)
#     242 if action is not None \
#     243         and not self.config["manual_control"] \
#     244         and self.steps % int(self.config["simulation_frequency"] // self.config["policy_frequency"]) == 0:
#     245     self.action_type.act(action)
# --> 247 self.road.act()
#     248 self.road.step(1 / self.config["simulation_frequency"])
#     249 self.steps += 1
#
# File ~/.local/lib/python3.10/site-packages/highway_env/road/road.py:324, in Road.act(self)
#     322 """Decide the actions of each entity on the road."""
#     323 for vehicle in self.vehicles:
# --> 324     vehicle.act()
#
# File ~/.local/lib/python3.10/site-packages/highway_env/vehicle/controller.py:248, in MDPVehicle.act(self, action)
#     246     self.speed_index = self.speed_to_index(self.speed) - 1
#     247 else:
# --> 248     super().act(action)
#     249     return
#     250 self.speed_index = int(np.clip(self.speed_index, 0, self.target_speeds.size - 1))
#
# File ~/.local/lib/python3.10/site-packages/highway_env/vehicle/controller.py:105, in ControlledVehicle.act(self, action)
#     101         self.target_lane_index = target_lane_index
#     103 action = {"steering": self.steering_control(self.target_lane_index),
#     104           "acceleration": self.speed_control(self.target_speed)}
# --> 105 action['steering'] = np.clip(action['steering'], -self.MAX_STEERING_ANGLE, self.MAX_STEERING_ANGLE)
#     106 super().act(action)
#
# File <__array_function__ internals>:180, in clip(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2154, in clip(a, a_min, a_max, out, **kwargs)
#    2085 @array_function_dispatch(_clip_dispatcher)
#    2086 def clip(a, a_min, a_max, out=None, **kwargs):
#    2087     """
#    2088     Clip (limit) the values in an array.
#    2089
#    (...)
#    2152
#    2153     """
# -> 2154     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      52 bound = getattr(obj, method, None)
#      53 if bound is None:
# ---> 54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
#      57     return bound(*args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:43, in _wrapit(obj, method, *args, **kwds)
#      41 except AttributeError:
#      42     wrap = None
# ---> 43 result = getattr(asarray(obj), method)(*args, **kwds)
#      44 if wrap:
#      45     if not isinstance(result, mu.ndarray):
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py:133, in _clip(a, min, max, out, casting, **kwargs)
#     128     raise ValueError("One of max or min must be given")
#     130 # Numpy 1.17.0, 2019-02-24
#     131 # This deprecation probably incurs a substantial slowdown for small arrays,
#     132 # it will be good to get rid of it.
# --> 133 if not _clip_dep_is_byte_swapped(a) and not _clip_dep_is_byte_swapped(out):
#     134     using_deprecated_nan = False
#     135     if _clip_dep_is_scalar_nan(min):
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py:103, in _clip_dep_is_byte_swapped(a)
#     102 def _clip_dep_is_byte_swapped(a):
# --> 103     if isinstance(a, mu.ndarray):
#     104         return not a.dtype.isnative
#     105     return False
#
# KeyboardInterrupt:

# %%
import gym
import numpy as np
import torch as th
import matplotlib.pyplot as plt

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# %%
mean_reward, std_reward = evaluate_policy(model1, model1.get_env(), deterministic=True, n_eval_episodes=20)

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:37.89 +/- 1.17

# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import TD3
from stable_baselines3 import SAC
from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print(f"Saving new best model to {self.save_path}.zip")
                  self.model.save(self.save_path)

        return True

# %%
# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env4 = gym.make('highway-v0')
# Logs will be saved in log_dir/monitor.csv
env4 = Monitor(env4, log_dir)
# Out:
# /home/rohit/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:31: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (5, 5)
#   logger.warn(

# %%
# Create action noise because TD3 and DDPG use a deterministic policy
#n_actions = env4.action_space.shape[]
#action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)
# Create RL model
model4 = A2C('MlpPolicy', env4 , verbose=0)
# Train the agent
model4.learn(total_timesteps=int(5e4), callback=callback)
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: 14.25
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2000
# Best mean reward: 14.25 - Last mean reward per episode: 18.32
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3000
# Best mean reward: 18.32 - Last mean reward per episode: 20.95
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4000
# Best mean reward: 20.95 - Last mean reward per episode: 25.17
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5000
# Best mean reward: 25.17 - Last mean reward per episode: 27.26
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6000
# Best mean reward: 27.26 - Last mean reward per episode: 27.65
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7000
# Best mean reward: 27.65 - Last mean reward per episode: 25.25
# Num timesteps: 8000
# Best mean reward: 27.65 - Last mean reward per episode: 14.51
# Num timesteps: 9000
# Best mean reward: 27.65 - Last mean reward per episode: 10.91
# Num timesteps: 10000
# Best mean reward: 27.65 - Last mean reward per episode: 9.95
# Num timesteps: 11000
# Best mean reward: 27.65 - Last mean reward per episode: 8.67
# Num timesteps: 12000
# Best mean reward: 27.65 - Last mean reward per episode: 8.86
# Num timesteps: 13000
# Best mean reward: 27.65 - Last mean reward per episode: 8.84
# Num timesteps: 14000
# Best mean reward: 27.65 - Last mean reward per episode: 8.88
# Num timesteps: 15000
# Best mean reward: 27.65 - Last mean reward per episode: 8.16
# Num timesteps: 16000
# Best mean reward: 27.65 - Last mean reward per episode: 9.61
# Num timesteps: 17000
# Best mean reward: 27.65 - Last mean reward per episode: 8.80
# Num timesteps: 18000
# Best mean reward: 27.65 - Last mean reward per episode: 8.05
# Num timesteps: 19000
# Best mean reward: 27.65 - Last mean reward per episode: 8.99
# Num timesteps: 20000
# Best mean reward: 27.65 - Last mean reward per episode: 8.48
# Num timesteps: 21000
# Best mean reward: 27.65 - Last mean reward per episode: 8.22
# Num timesteps: 22000
# Best mean reward: 27.65 - Last mean reward per episode: 8.87
# Num timesteps: 23000
# Best mean reward: 27.65 - Last mean reward per episode: 9.53
# Num timesteps: 24000
# Best mean reward: 27.65 - Last mean reward per episode: 9.51
# Num timesteps: 25000
# Best mean reward: 27.65 - Last mean reward per episode: 9.43
# Num timesteps: 26000
# Best mean reward: 27.65 - Last mean reward per episode: 9.31
# Num timesteps: 27000
# Best mean reward: 27.65 - Last mean reward per episode: 9.41
# Num timesteps: 28000
# Best mean reward: 27.65 - Last mean reward per episode: 8.01
# Num timesteps: 29000
# Best mean reward: 27.65 - Last mean reward per episode: 9.03
# Num timesteps: 30000
# Best mean reward: 27.65 - Last mean reward per episode: 8.55
# Num timesteps: 31000
# Best mean reward: 27.65 - Last mean reward per episode: 8.59
# Num timesteps: 32000
# Best mean reward: 27.65 - Last mean reward per episode: 8.49
# Num timesteps: 33000
# Best mean reward: 27.65 - Last mean reward per episode: 8.51
# Num timesteps: 34000
# Best mean reward: 27.65 - Last mean reward per episode: 8.64
# Num timesteps: 35000
# Best mean reward: 27.65 - Last mean reward per episode: 8.50
# Num timesteps: 36000
# Best mean reward: 27.65 - Last mean reward per episode: 9.09
# Num timesteps: 37000
# Best mean reward: 27.65 - Last mean reward per episode: 7.95
# Num timesteps: 38000
# Best mean reward: 27.65 - Last mean reward per episode: 8.45
# Num timesteps: 39000
# Best mean reward: 27.65 - Last mean reward per episode: 8.42
# Num timesteps: 40000
# Best mean reward: 27.65 - Last mean reward per episode: 8.75
# Num timesteps: 41000
# Best mean reward: 27.65 - Last mean reward per episode: 8.46
# Num timesteps: 42000
# Best mean reward: 27.65 - Last mean reward per episode: 9.23
# Num timesteps: 43000
# Best mean reward: 27.65 - Last mean reward per episode: 8.04
# Num timesteps: 44000
# Best mean reward: 27.65 - Last mean reward per episode: 8.13
# Num timesteps: 45000
# Best mean reward: 27.65 - Last mean reward per episode: 9.90
# Num timesteps: 46000
# Best mean reward: 27.65 - Last mean reward per episode: 8.20
# Num timesteps: 47000
# Best mean reward: 27.65 - Last mean reward per episode: 8.83
# Num timesteps: 48000
# Best mean reward: 27.65 - Last mean reward per episode: 9.58
# Num timesteps: 49000
# Best mean reward: 27.65 - Last mean reward per episode: 7.08
# Num timesteps: 50000
# Best mean reward: 27.65 - Last mean reward per episode: 8.19

# %%
from stable_baselines3 import DQN

model1 = DQN.load("highway_dqn/model1",env=env1)
model2 = DQN.load("highway_dqn/model2",env=env2)
while True:
  vec_env1=model1.get_env()
  done = truncated = False
  obs1 = vec_env1.reset()

  vec_env2=model2.get_env()
  done = truncated = False
  obs2 = vec_env2.reset()

  vec_env3=model1.get_env()
  done = truncated = False
  obs3 = vec_env3.reset()


  #print(info)
  while not (done or truncated):
    action1, _states1 = model1.predict(obs1, deterministic=True)
    action2, _states2 = model2.predict(obs2, deterministic=True)

    action = tuple(model1.predict(obs1, deterministic=True))
    obs1, reward1, done1, info1= vec_env1.step(action1)
    obs2, reward2, done2, info2 = vec_env2.step(action2)
    vec_env3.metadata['render_fps'] = 14
    vec_env3.step((action1[0], action2[0]))
    #vec_env3.render()
    #vec_env1.render()
    vec_env3.render()

# %%
from stable_baselines3.common import results_plotter

# Helper from the library
results_plotter.plot_results([log_dir], 1e5, results_plotter.X_TIMESTEPS, "A2C Highway Env")

# %%
def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), 'timesteps')
    y = moving_average(y, window=50)
    # Truncate x
    x = x[len(x) - len(y):]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title + " Smoothed")
    plt.show()

# %%
plot_results(log_dir)
