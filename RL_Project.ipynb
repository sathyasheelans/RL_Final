# %%
import gym
import highway_env
from stable_baselines3 import DQN

env = gym.make("highway-v0")
model = DQN('MlpPolicy', env,
              policy_kwargs=dict(net_arch=[256, 256]),
              learning_rate=5e-4,
              buffer_size=15000,
              learning_starts=200,
              batch_size=32,
              gamma=0.8,
              train_freq=1,
              gradient_steps=1,
              target_update_interval=50,
              verbose=1,
              tensorboard_log="highway_dqn/")
model.learn(int(2e4))
model.save("highway_dqn/model")

# Load and test saved model

# %%
model = DQN.load("highway_dqn/model",env=env)
while True:
  vec_env=model.get_env()
  done = truncated = False
  obs = vec_env.reset()
  print(info)
  while not (done or truncated):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done,info= vec_env.step(action)
    env.metadata['render_fps'] = 14
    vec_env.render()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# [{'speed': 20.000000000896662, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 8.966622999651008e-11, 'on_road_reward': 1.0}, 'episode': {'r': 22.152263, 'l': 30, 't': 23.810337}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25      ,  0.        ],
#        [ 1.        ,  0.0793642 ,  0.        ,  0.00949505,  0.        ],
#        [ 1.        ,  0.1417434 , -0.6666667 , -0.01589997,  0.        ],
#        [ 1.        ,  0.22922492, -0.33333334,  0.01142651,  0.        ],
#        [ 1.        ,  0.39113882, -0.6666667 , -0.01280058,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000003034236844, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.0342368440017253e-07, 'on_road_reward': 1.0}, 'episode': {'r': 23.452266, 'l': 30, 't': 0.865146}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25000003,  0.        ],
#        [ 1.        ,  0.01997263, -0.6666667 ,  0.0020937 ,  0.        ],
#        [ 1.        ,  0.06991803,  0.        ,  0.00570621,  0.        ],
#        [ 1.        ,  0.09528053, -0.33333334, -0.01196644,  0.        ],
#        [ 1.        ,  0.36498886, -0.33333334, -0.00941697,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000000000000004, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.552713678800501e-16, 'on_road_reward': 1.0}, 'episode': {'r': 23.984964, 'l': 30, 't': 1.69769}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25      ,  0.        ],
#        [ 1.        ,  0.01195088, -0.6666667 ,  0.00358754,  0.        ],
#        [ 1.        , -0.03728713, -0.33333334, -0.0062749 ,  0.        ],
#        [ 1.        ,  0.24449517, -0.33333334, -0.00102396,  0.        ],
#        [ 1.        ,  0.2473786 ,  0.        ,  0.00246538,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.00017496848987, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 1.7496848986908732e-05, 'on_road_reward': 1.0}, 'episode': {'r': 25.62022, 'l': 30, 't': 2.561665}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25000218,  0.        ],
#        [ 1.        ,  0.00611377, -0.6666667 ,  0.01071478,  0.        ],
#        [ 1.        ,  0.03801502,  0.        ,  0.00438574,  0.        ],
#        [ 1.        ,  0.18084022, -0.33333334, -0.00542606,  0.        ],
#        [ 1.        ,  0.44536018,  0.        ,  0.01013333,  0.        ]],
#       dtype=float32)}]
# [{'speed': 16.000004128739725, 'crashed': True, 'action': 0, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 0.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 8.152932, 'l': 12, 't': 2.931376}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  2.2204460e-16,  2.0000005e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00, -3.6690070e-03,  3.3333334e-01,  5.9451662e-02,
#         -5.6621374e-15],
#        [ 1.0000000e+00,  2.5000000e-02, -1.1102230e-16, -7.9543535e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.2572064e-01,  6.6666669e-01,  3.5211865e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.3055159e-01, -1.1102230e-16,  5.3215511e-02,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.104049179473506, 'crashed': True, 'action': 0, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 0.0, 'high_speed_reward': 0.01040491794735061, 'on_road_reward': 1.0}, 'episode': {'r': 11.066778, 'l': 13, 't': 3.297491}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  0.0000000e+00,  2.5130060e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.5000000e-02,  0.0000000e+00, -6.8846874e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00, -3.4466654e-02,  6.6666669e-01,  4.6190736e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.3163909e-01,  3.3333334e-01,  4.7855624e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.8124821e-01,  9.9920072e-15, -2.8382568e-02,
#         -4.1078252e-15]], dtype=float32)}]
# [{'speed': 16.000004663032108, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 9.353554, 'l': 12, 't': 3.634562}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.20000006,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.02905236,  0.        ],
#        [ 1.        ,  0.1023341 , -0.6666667 ,  0.0685768 ,  0.        ],
#        [ 1.        ,  0.23843248,  0.        ,  0.01594047,  0.        ],
#        [ 1.        ,  0.30234772, -0.33333334,  0.05544314,  0.        ]],
#       dtype=float32)}]
# [{'speed': 29.99999954872593, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 0.5, 'high_speed_reward': 0.9982299501289859, 'on_road_reward': 1.0}, 'episode': {'r': 27.076716, 'l': 30, 't': 4.456856}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.30860123,  0.37477875,  0.01287979],
#        [ 1.        ,  0.0198417 , -0.30860123, -0.10026901, -0.01287979],
#        [ 1.        ,  0.11913059,  0.35806546, -0.13409398, -0.01287979],
#        [ 1.        ,  0.25988063,  0.02473212, -0.12274099, -0.01287979],
#        [ 1.        ,  0.46391195,  0.35806546, -0.12815341, -0.01287979]],
#       dtype=float32)}]
# [{'speed': 12.800251956307786, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 13.552927, 'l': 17, 't': 4.956334}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.16000316,  0.        ],
#        [ 1.        ,  0.02071877, -0.6666667 ,  0.09209996,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.00936016,  0.        ],
#        [ 1.        ,  0.18544562, -0.33333334,  0.07338254,  0.        ],
#        [ 1.        ,  0.32754895,  0.        ,  0.08713476,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.73222193589896, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.07322219358989593, 'on_road_reward': 1.0}, 'episode': {'r': 25.449239, 'l': 30, 't': 5.838386}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25915277,  0.        ],
#        [ 1.        ,  0.00900081, -0.33333334, -0.00966808,  0.        ],
#        [ 1.        ,  0.03152623,  0.        ,  0.0016091 ,  0.        ],
#        [ 1.        ,  0.24848323, -0.6666667 , -0.00563052,  0.        ],
#        [ 1.        ,  0.41923714, -0.33333334, -0.00266613,  0.        ]],
#       dtype=float32)}]
# [{'speed': 12.800000735412988, 'crashed': True, 'action': 2, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 8.885803, 'l': 12, 't': 6.250225}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  1.6000001e-01,
#          7.7715612e-14],
#        [ 1.0000000e+00,  2.5000000e-02,  1.2434498e-14, -7.6635438e-03,
#         -7.7604589e-14],
#        [ 1.0000000e+00,  2.1593325e-01, -6.6666669e-01,  8.9520313e-02,
#         -7.7604589e-14],
#        [ 1.0000000e+00,  2.8432998e-01, -3.3333334e-01,  1.0305451e-01,
#         -7.7604589e-14],
#        [ 1.0000000e+00,  3.2503426e-01, -3.8080650e-14,  8.5187741e-02,
#         -6.1284311e-14]], dtype=float32)}]
# [{'speed': 13.873006512390509, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 8.261844, 'l': 10, 't': 6.52983}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666311e-01,  1.7341258e-01,
#          2.3614104e-05],
#        [ 1.0000000e+00,  2.5000680e-02,  1.1627721e-05, -2.2907332e-02,
#         -2.3614102e-05],
#        [ 1.0000000e+00,  3.3967000e-02, -6.6666311e-01,  9.0301909e-02,
#         -2.3614104e-05],
#        [ 1.0000000e+00,  1.7232032e-01, -3.3332977e-01,  6.7538731e-02,
#         -2.3614104e-05],
#        [ 1.0000000e+00,  2.7771074e-01,  3.5689188e-06,  6.0964260e-02,
#         -2.3614104e-05]], dtype=float32)}]
# [{'speed': 24.341586436398533, 'crashed': False, 'action': 3, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 0.0, 'high_speed_reward': 0.4341586436398533, 'on_road_reward': 1.0}, 'episode': {'r': 23.801152, 'l': 30, 't': 7.352445}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.        ,  0.30426982,  0.        ],
#        [ 1.        , -0.03028283,  0.6666667 , -0.05265943,  0.        ],
#        [ 1.        ,  0.09953661,  0.        , -0.04173468,  0.        ],
#        [ 1.        ,  0.1256929 ,  0.33333334, -0.05327377,  0.        ],
#        [ 1.        ,  0.26399302,  0.6666667 , -0.05193661,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000023145428386, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 2.3145428386328605e-06, 'on_road_reward': 1.0}, 'episode': {'r': 22.952052, 'l': 30, 't': 8.23037}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000030e-01,
#          2.2204460e-16],
#        [ 1.0000000e+00, -2.1854751e-02, -6.6666669e-01,  1.5065618e-02,
#         -2.2204460e-16],
#        [ 1.0000000e+00,  7.9294927e-02, -3.3333334e-01,  9.7995084e-03,
#         -2.2204460e-16],
#        [ 1.0000000e+00,  9.2147239e-02,  2.2204460e-16, -4.9774526e-03,
#         -2.2204460e-16],
#        [ 1.0000000e+00,  3.8158497e-01,  2.2204460e-16, -4.4804765e-03,
#         -2.2204460e-16]], dtype=float32)}]
# [{'speed': 20.096447329971863, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.009644732997186267, 'on_road_reward': 1.0}, 'episode': {'r': 25.784637, 'l': 30, 't': 9.063124}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.2512056 ,  0.        ],
#        [ 1.        , -0.00771552, -0.33333334,  0.01530606,  0.        ],
#        [ 1.        ,  0.09427381, -0.6666667 , -0.00964079,  0.        ],
#        [ 1.        ,  0.09901472,  0.        ,  0.02020974,  0.        ],
#        [ 1.        ,  0.35806638, -0.33333334,  0.01307883,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000000000000004, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.552713678800501e-16, 'on_road_reward': 1.0}, 'episode': {'r': 22.286265, 'l': 30, 't': 9.862407}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25      ,  0.        ],
#        [ 1.        ,  0.12654576,  0.        ,  0.00623692,  0.        ],
#        [ 1.        ,  0.14663032, -0.33333334, -0.00279341,  0.        ],
#        [ 1.        ,  0.3523467 , -0.6666667 ,  0.00460161,  0.        ],
#        [ 1.        ,  0.41837278,  0.        ,  0.00522842,  0.        ]],
#       dtype=float32)}]
# [{'speed': 8.192000000042023, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 16.151308, 'l': 21, 't': 10.464584}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  1.0240000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00, -1.1724163e-02, -6.6666669e-01,  1.5642798e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.5000000e-02,  2.2204460e-16, -6.2126509e-04,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.2568012e-01, -3.3333334e-01,  1.4167647e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.6993697e-01,  0.0000000e+00,  1.4753732e-01,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.00002264281618, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 2.264281618025166e-06, 'on_road_reward': 1.0}, 'episode': {'r': 24.252266, 'l': 30, 't': 11.297669}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25000027,  0.        ],
#        [ 1.        ,  0.09427924,  0.        ,  0.01217181,  0.        ],
#        [ 1.        ,  0.15337723, -0.33333334,  0.00980513,  0.        ],
#        [ 1.        ,  0.23854262, -0.6666667 , -0.00452276,  0.        ],
#        [ 1.        ,  0.45182332,  0.        ,  0.01590889,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000000000000004, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.552713678800501e-16, 'on_road_reward': 1.0}, 'episode': {'r': 22.653092, 'l': 30, 't': 12.149719}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.00000000e+00,  1.00000000e+00,  6.66666687e-01,
#          2.50000000e-01,  0.00000000e+00],
#        [ 1.00000000e+00, -1.06185237e-02, -6.66666687e-01,
#          4.25749226e-03,  0.00000000e+00],
#        [ 1.00000000e+00, -3.05840503e-02, -3.33333343e-01,
#         -8.53821053e-04,  0.00000000e+00],
#        [ 1.00000000e+00,  1.20481424e-01,  0.00000000e+00,
#         -1.51874311e-02,  0.00000000e+00],
#        [ 1.00000000e+00,  2.66570777e-01, -3.33333343e-01,
#         -3.91327449e-05,  0.00000000e+00]], dtype=float32)}]
# [{'speed': 20.001675578464067, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.00016755784640665183, 'on_road_reward': 1.0}, 'episode': {'r': 4.153548, 'l': 6, 't': 12.321338}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6999829e-01,  2.5002095e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.2320824e-02, -2.4419621e-01, -7.2277099e-02,
#         -3.7734095e-02],
#        [ 1.0000000e+00,  8.1533834e-02, -6.6827875e-01,  1.6866019e-02,
#         -7.7284215e-04],
#        [ 1.0000000e+00,  1.9668658e-01, -2.3942162e-01, -3.1330008e-02,
#         -4.0434301e-02],
#        [ 1.0000000e+00,  4.1567776e-01, -3.3317627e-03,  1.0935996e-02,
#          5.5524065e-08]], dtype=float32)}]
# [{'speed': 20.075289359173258, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0075289359173257965, 'on_road_reward': 1.0}, 'episode': {'r': 24.518628, 'l': 30, 't': 13.158971}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5094113e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00, -4.9955145e-02, -3.3333334e-01, -6.9891526e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.0004448e-01,  2.2204460e-16,  2.0052383e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.9932449e-01, -6.6666669e-01,  1.3071245e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.0903507e-01, -3.3333334e-01, -6.1946046e-03,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 16.000000063449356, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 20.286266, 'l': 24, 't': 13.823749}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.2       ,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.01431898,  0.        ],
#        [ 1.        ,  0.09762157, -0.33333334,  0.06111218,  0.        ],
#        [ 1.        ,  0.12654538, -0.6666667 ,  0.05779178,  0.        ],
#        [ 1.        ,  0.31043   ,  0.        ,  0.04005626,  0.        ]],
#       dtype=float32)}]
# [{'speed': 10.240006625622062, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 16.585032, 'l': 21, 't': 14.405833}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.12800008,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.0096216 ,  0.        ],
#        [ 1.        ,  0.25002068, -0.33333334,  0.1273217 ,  0.        ],
#        [ 1.        ,  0.26652035, -0.6666667 ,  0.13120128,  0.        ],
#        [ 1.        ,  0.29334113,  0.        ,  0.1020923 ,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000000000000004, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.552713678800501e-16, 'on_road_reward': 1.0}, 'episode': {'r': 22.918933, 'l': 30, 't': 15.249419}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25      ,  0.        ],
#        [ 1.        ,  0.02532212, -0.33333334,  0.00262307,  0.        ],
#        [ 1.        ,  0.06069135,  0.        , -0.00500877,  0.        ],
#        [ 1.        ,  0.24721435, -0.6666667 , -0.00342196,  0.        ],
#        [ 1.        ,  0.340943  , -0.33333334,  0.00755586,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000000000000004, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.552713678800501e-16, 'on_road_reward': 1.0}, 'episode': {'r': 22.75247, 'l': 30, 't': 16.083151}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.2881638e-01,  2.2204460e-16,  1.2124095e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.2298452e-01, -6.6666669e-01,  3.0087873e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.5302544e-01, -3.3333334e-01,  3.4216391e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  5.0519156e-01,  0.0000000e+00,  1.1706246e-02,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 24.92320699843992, 'crashed': True, 'action': 1, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.49232069984399196, 'on_road_reward': 1.0}, 'episode': {'r': 16.765689, 'l': 22, 't': 16.681851}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.3115401 ,  0.        ],
#        [ 1.        ,  0.01428513, -0.33333334, -0.06224554,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.05656976,  0.        ],
#        [ 1.        ,  0.35252836, -0.33333334, -0.06474244,  0.        ],
#        [ 1.        ,  0.38020703, -0.6666667 , -0.06066718,  0.        ]],
#       dtype=float32)}]
# [{'speed': 12.800000000003015, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 22.918395, 'l': 30, 't': 17.493275}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  1.6000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.5000000e-02, -1.1102230e-16, -7.0586805e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  5.0215375e-02, -6.6666669e-01,  9.1895983e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.4808042e-01, -3.3333334e-01,  1.0658379e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.2647333e-01, -1.1102230e-16,  8.1400119e-02,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 8.19200000190069, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 11.752932, 'l': 16, 't': 17.932197}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.1024    ,  0.        ],
#        [ 1.        , -0.00314849, -0.33333334,  0.15417533,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.00625615,  0.        ],
#        [ 1.        ,  0.3132434 ,  0.        ,  0.13039178,  0.        ],
#        [ 1.        ,  0.33056438, -0.6666667 ,  0.16208245,  0.        ]],
#       dtype=float32)}]
# [{'speed': 11.527608582700214, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 8.496378, 'l': 10, 't': 18.215969}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6671538e-01,  1.4409511e-01,
#          3.5277149e-05],
#        [ 1.0000000e+00,  2.5001224e-02, -2.6578420e-05, -2.2531239e-02,
#         -3.5277149e-05],
#        [ 1.0000000e+00,  2.8574893e-02, -6.6671538e-01,  1.2757571e-01,
#         -3.5277149e-05],
#        [ 1.0000000e+00,  1.6364804e-01, -3.3338204e-01,  1.0313714e-01,
#         -3.5277149e-05],
#        [ 1.0000000e+00,  2.7696034e-01, -4.8719125e-05,  9.8420776e-02,
#         -3.5277149e-05]], dtype=float32)}]
# [{'speed': 20.00000000692917, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 6.929170126568351e-10, 'on_road_reward': 1.0}, 'episode': {'r': 25.585599, 'l': 30, 't': 19.023192}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00, -2.4274798e-02, -6.6666669e-01,  3.8133748e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  4.6872083e-02, -1.1102230e-16, -1.1686514e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  6.0364224e-02, -3.3333334e-01,  6.4384947e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.3876726e-01, -6.6666669e-01,  1.3943796e-02,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 16.77662830167283, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 24.633216, 'l': 30, 't': 19.835687}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.20970786,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.0023635 ,  0.        ],
#        [ 1.        , -0.03732629, -0.33333334,  0.03429187,  0.        ],
#        [ 1.        ,  0.27389026, -0.6666667 ,  0.05040503,  0.        ],
#        [ 1.        ,  0.30076125, -0.33333334,  0.0392406 ,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000000000000004, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.552713678800501e-16, 'on_road_reward': 1.0}, 'episode': {'r': 23.95247, 'l': 30, 't': 20.641366}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.7624355e-02, -1.1102230e-16,  3.2734072e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.8131855e-01, -3.3333334e-01,  8.2423650e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.5331804e-01, -6.6666669e-01,  9.2267124e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.5544136e-01, -3.3306691e-16,  9.5409341e-03,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.58465049901397, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.058465049901397136, 'on_road_reward': 1.0}, 'episode': {'r': 25.816896, 'l': 30, 't': 21.451201}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5730813e-01,
#         -2.6555314e-11],
#        [ 1.0000000e+00, -1.7461559e-02, -6.6666669e-01, -2.1448052e-03,
#          2.6555202e-11],
#        [ 1.0000000e+00,  8.5794166e-02, -6.1173289e-11,  4.0640291e-03,
#          2.6555202e-11],
#        [ 1.0000000e+00,  1.8357500e-01, -3.3333334e-01, -5.2795437e-04,
#          2.6555202e-11],
#        [ 1.0000000e+00,  3.4584457e-01, -6.6666669e-01,  5.6940690e-03,
#          2.6555202e-11]], dtype=float32)}]
# [{'speed': 20.000000060580117, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 6.0580116922892556e-09, 'on_road_reward': 1.0}, 'episode': {'r': 27.353555, 'l': 30, 't': 22.266716}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  8.8900901e-02,  0.0000000e+00,  8.3084090e-04,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.5782148e-01, -6.6666669e-01, -3.4506628e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.1295774e-01, -3.3333334e-01,  7.0213694e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  4.5945048e-01, -1.1102230e-16,  7.5936411e-03,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.000025674995122, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 2.5674995121960364e-06, 'on_road_reward': 1.0}, 'episode': {'r': 23.685021, 'l': 30, 't': 23.076841}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000033e-01,
#          2.2204460e-16],
#        [ 1.0000000e+00,  3.0074619e-02, -3.3333334e-01, -2.9874663e-03,
#         -2.2204460e-16],
#        [ 1.0000000e+00,  7.9064086e-02,  2.2204460e-16, -8.9305727e-04,
#         -2.2204460e-16],
#        [ 1.0000000e+00,  1.5508153e-01, -6.6666669e-01,  6.1647408e-03,
#         -2.2204460e-16],
#        [ 1.0000000e+00,  3.8240874e-01, -3.3333334e-01, -3.2253999e-03,
#         -2.2204460e-16]], dtype=float32)}]
# [{'speed': 13.854399577715673, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 18.131067, 'l': 24, 't': 23.723382}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.17318   ,  0.        ],
#        [ 1.        , -0.00223396, -0.6666667 ,  0.06883726,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.00949624,  0.        ],
#        [ 1.        ,  0.17863491, -0.33333334,  0.07408036,  0.        ],
#        [ 1.        ,  0.2871681 , -0.6666667 ,  0.07729442,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000000000153893, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 1.538928984246013e-11, 'on_road_reward': 1.0}, 'episode': {'r': 26.686888, 'l': 30, 't': 24.541736}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25      ,  0.        ],
#        [ 1.        ,  0.11306311,  0.        , -0.00239885,  0.        ],
#        [ 1.        ,  0.18293521, -0.6666667 ,  0.0122629 ,  0.        ],
#        [ 1.        ,  0.3159799 , -0.33333334,  0.01358544,  0.        ],
#        [ 1.        ,  0.39615634,  0.        , -0.00402884,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.000029056958073, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 2.9056958073425678e-06, 'on_road_reward': 1.0}, 'episode': {'r': 23.819136, 'l': 30, 't': 25.344615}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000036e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  4.5542434e-02,  2.2204460e-16, -1.1142590e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.2976618e-01, -3.3333334e-01,  2.7339887e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.5960222e-01, -6.6666669e-01,  4.6603219e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.7158039e-01,  2.2204460e-16, -7.4981549e-03,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 8.192000000032815, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 20.419599, 'l': 26, 't': 26.12734}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.1024    ,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.00163095,  0.        ],
#        [ 1.        ,  0.04333797, -0.6666667 ,  0.15797761,  0.        ],
#        [ 1.        ,  0.09938382, -0.33333334,  0.1331731 ,  0.        ],
#        [ 1.        ,  0.34533462, -0.33333334,  0.13672796,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.076961502933184, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.007696150293318382, 'on_road_reward': 1.0}, 'episode': {'r': 24.685954, 'l': 30, 't': 26.940742}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5096202e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.2925453e-02, -6.6666669e-01,  4.7601608e-04,
#          0.0000000e+00],
#        [ 1.0000000e+00,  7.4843623e-02,  0.0000000e+00,  1.2912798e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.1930932e-01, -3.3333334e-01, -4.9555656e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.7932670e-01, -6.6666669e-01,  7.4077202e-03,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.000000000000345, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.4461322684364856e-14, 'on_road_reward': 1.0}, 'episode': {'r': 23.519058, 'l': 30, 't': 27.762509}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  8.1117153e-03, -6.6666669e-01,  4.4415221e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  5.2957378e-02,  2.2204460e-16,  7.3570461e-04,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.2664917e-01, -3.3333334e-01, -2.7799667e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.5508457e-01, -6.6666669e-01,  1.1099358e-02,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 8.192000000000096, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 15.786425, 'l': 21, 't': 28.329489}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.1024    ,  0.        ],
#        [ 1.        ,  0.025     ,  0.        , -0.00219786,  0.        ],
#        [ 1.        ,  0.17462339, -0.33333334,  0.15381642,  0.        ],
#        [ 1.        ,  0.23564504, -0.6666667 ,  0.14585389,  0.        ],
#        [ 1.        ,  0.35626918,  0.        ,  0.15005443,  0.        ]],
#       dtype=float32)}]
# [{'speed': 24.41815877694635, 'crashed': False, 'action': 3, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.44181587769463493, 'on_road_reward': 1.0}, 'episode': {'r': 24.701729, 'l': 30, 't': 29.161232}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  3.0522698e-01,
#          3.1249665e-09],
#        [ 1.0000000e+00,  2.6490711e-02, -6.6666669e-01, -4.7797780e-02,
#         -3.1249665e-09],
#        [ 1.0000000e+00,  4.9869098e-02,  6.2956027e-09, -4.2202059e-02,
#         -3.1249665e-09],
#        [ 1.0000000e+00,  1.8542501e-01, -3.3333331e-01, -4.4712704e-02,
#         -3.1249665e-09],
#        [ 1.0000000e+00,  3.6821663e-01, -6.6666669e-01, -4.0830608e-02,
#         -3.1249665e-09]], dtype=float32)}]
# [{'speed': 20.000000051826543, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 5.182654305713186e-09, 'on_road_reward': 1.0}, 'episode': {'r': 24.484361, 'l': 30, 't': 29.978541}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  5.2063052e-02, -1.1102230e-16, -6.3564172e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  7.6202616e-02, -3.3333334e-01,  1.5486174e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.6076717e-01, -6.6666669e-01, -7.8510502e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.4645316e-01, -3.6948222e-13,  7.7929022e-03,
#          1.6320278e-13]], dtype=float32)}]
# [{'speed': 11.60533320985569, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 0.0, 'high_speed_reward': 0.0, 'on_road_reward': 1.0}, 'episode': {'r': 9.87849, 'l': 12, 't': 30.314589}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  2.2204460e-16,  1.4506666e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00, -4.2320709e-03,  3.3333334e-01,  1.0377499e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.5000000e-02, -1.1102230e-16, -4.9101513e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.8456903e-01,  3.3333334e-01,  1.1335199e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.8749749e-01, -1.1102230e-16,  1.0300838e-01,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.000000000015586, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 1.5585754908897797e-12, 'on_road_reward': 1.0}, 'episode': {'r': 23.718933, 'l': 30, 't': 31.118717}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  9.8439328e-02,  2.2204460e-16,  8.9677246e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.0007560e-01, -3.3333334e-01,  9.4978893e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.1104887e-01, -6.6666669e-01,  7.0262179e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  4.7298080e-01,  2.2204460e-16,  3.0463599e-03,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.075312444293417, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0075312444293416545, 'on_road_reward': 1.0}, 'episode': {'r': 23.45196, 'l': 30, 't': 31.938679}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5094140e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  8.6298704e-02, -6.6666669e-01, -1.1953039e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  9.4894595e-02,  2.2204460e-16,  1.7818432e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.7306720e-01, -3.3333334e-01,  1.8084330e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.8563576e-01, -6.6666669e-01, -9.3490826e-03,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.571904319097076, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.05719043190970759, 'on_road_reward': 1.0}, 'episode': {'r': 26.417908, 'l': 30, 't': 32.756092}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.2571488 ,  0.        ],
#        [ 1.        , -0.0391393 , -0.6666667 , -0.01109594,  0.        ],
#        [ 1.        ,  0.08978753, -0.33333334, -0.00508414,  0.        ],
#        [ 1.        ,  0.10616083,  0.        ,  0.02036587,  0.        ],
#        [ 1.        ,  0.22640714, -0.6666667 , -0.0103588 ,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.73239768274144, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.07323976827414391, 'on_road_reward': 1.0}, 'episode': {'r': 25.483926, 'l': 30, 't': 33.573903}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5915498e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  4.7395431e-02,  0.0000000e+00,  5.0659976e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.8953093e-01, -3.3333334e-01, -1.5418321e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.0121884e-01, -6.6666669e-01, -8.8949193e-04,
#          0.0000000e+00],
#        [ 1.0000000e+00,  4.2110527e-01, -1.1102230e-16, -5.6003872e-04,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.000000000000004, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.552713678800501e-16, 'on_road_reward': 1.0}, 'episode': {'r': 23.817974, 'l': 30, 't': 34.416984}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25      ,  0.        ],
#        [ 1.        , -0.01612721, -0.33333334, -0.01359922,  0.        ],
#        [ 1.        ,  0.04285179,  0.        ,  0.00427444,  0.        ],
#        [ 1.        ,  0.07400855, -0.6666667 ,  0.01170476,  0.        ],
#        [ 1.        ,  0.2778486 , -0.33333334, -0.00984569,  0.        ]],
#       dtype=float32)}]
# [{'speed': 20.012697848486248, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.0012697848486247665, 'on_road_reward': 1.0}, 'episode': {'r': 23.585548, 'l': 30, 't': 35.221728}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.00000000e+00,  1.00000000e+00,  6.66666687e-01,
#          2.50158727e-01,  0.00000000e+00],
#        [ 1.00000000e+00,  1.36690745e-02, -6.66666687e-01,
#         -4.86569759e-03,  0.00000000e+00],
#        [ 1.00000000e+00,  5.67414686e-02, -1.11022302e-16,
#          1.35437213e-02,  0.00000000e+00],
#        [ 1.00000000e+00,  1.57604516e-01, -3.33333343e-01,
#         -6.40206644e-03,  0.00000000e+00],
#        [ 1.00000000e+00,  3.22640210e-01, -6.66666687e-01,
#         -1.74942799e-03,  0.00000000e+00]], dtype=float32)}]
# [{'speed': 24.341566820232195, 'crashed': False, 'action': 3, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.43415668202321955, 'on_road_reward': 1.0}, 'episode': {'r': 26.66933, 'l': 30, 't': 36.025046}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.00000000e+00,  1.00000000e+00,  6.66666687e-01,
#          3.04269582e-01,  0.00000000e+00],
#        [ 1.00000000e+00,  1.04968034e-01, -3.33333343e-01,
#         -7.14836642e-02,  0.00000000e+00],
#        [ 1.00000000e+00,  1.22728847e-01,  0.00000000e+00,
#         -3.36315669e-02,  0.00000000e+00],
#        [ 1.00000000e+00,  1.71067536e-01, -6.66666687e-01,
#         -4.85786162e-02,  0.00000000e+00],
#        [ 1.00000000e+00,  3.90132010e-01, -3.33333373e-01,
#         -5.87859079e-02,  1.39528469e-08]], dtype=float32)}]
# [{'speed': 25.65826084501937, 'crashed': True, 'action': 4, 'rewards': {'collision_reward': 1.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.5658249657615414, 'on_road_reward': 1.0}, 'episode': {'r': 7.395092, 'l': 9, 't': 36.277281}, 'TimeLimit.truncated': False, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6598314e-01,  3.2072812e-01,
#          2.9950441e-04],
#        [ 1.0000000e+00,  2.5009437e-02,  7.7533117e-04, -7.1873359e-02,
#         -2.9950441e-04],
#        [ 1.0000000e+00, -4.7401339e-02, -6.6598314e-01, -7.2744586e-02,
#         -2.9950441e-04],
#        [ 1.0000000e+00,  1.3692227e-01, -3.3264980e-01, -7.0745967e-02,
#         -2.9950441e-04],
#        [ 1.0000000e+00,  2.6671970e-01, -6.6598314e-01, -1.0081937e-01,
#         -2.9950441e-04]], dtype=float32)}]
# [{'speed': 20.000000000118085, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 1.1808509725597106e-11, 'on_road_reward': 1.0}, 'episode': {'r': 24.153555, 'l': 30, 't': 37.142298}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.        ,  1.        ,  0.6666667 ,  0.25      ,  0.        ],
#        [ 1.        , -0.01244231, -0.6666667 ,  0.00453422,  0.        ],
#        [ 1.        ,  0.03742754,  0.        , -0.00418388,  0.        ],
#        [ 1.        ,  0.05010724, -0.33333334,  0.01229292,  0.        ],
#        [ 1.        ,  0.3306548 ,  0.        , -0.00230367,  0.        ]],
#       dtype=float32)}]
# [{'speed': 24.341783986247783, 'crashed': False, 'action': 3, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.43417839862477836, 'on_road_reward': 1.0}, 'episode': {'r': 24.501374, 'l': 30, 't': 37.961896}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  3.0427229e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00, -4.1850474e-02, -6.6666669e-01, -6.6313870e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  7.5342745e-02, -3.3306691e-16, -3.4643959e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  1.5176898e-01, -3.3333334e-01, -3.7908409e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.4584404e-01, -6.6666669e-01, -5.9600130e-02,
#          0.0000000e+00]], dtype=float32)}]
# [{'speed': 20.001305632658898, 'crashed': False, 'action': 4, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.00013056326588980482, 'on_road_reward': 1.0}, 'episode': {'r': 24.952927, 'l': 30, 't': 38.776193}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.00000000e+00,  1.00000000e+00,  6.66666687e-01,
#          2.50016332e-01,  0.00000000e+00],
#        [ 1.00000000e+00, -2.59074438e-02, -3.33333343e-01,
#         -4.86568362e-03,  0.00000000e+00],
#        [ 1.00000000e+00,  1.19603835e-01, -6.66666687e-01,
#         -8.19901325e-05,  0.00000000e+00],
#        [ 1.00000000e+00,  1.21340103e-01,  0.00000000e+00,
#          1.03649311e-02,  0.00000000e+00],
#        [ 1.00000000e+00,  2.56458580e-01, -3.33333343e-01,
#         -6.37477124e-03,  0.00000000e+00]], dtype=float32)}]
# [{'speed': 20.000000000000004, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 3.552713678800501e-16, 'on_road_reward': 1.0}, 'episode': {'r': 23.419137, 'l': 30, 't': 39.606804}, 'TimeLimit.truncated': True, 'terminal_observation': array([[ 1.0000000e+00,  1.0000000e+00,  6.6666669e-01,  2.5000000e-01,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.5064027e-02, -3.3306691e-16, -3.6456815e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.0995055e-01, -6.6666669e-01,  1.4081338e-02,
#          0.0000000e+00],
#        [ 1.0000000e+00,  2.5360128e-01, -3.3333334e-01,  7.0790024e-03,
#          0.0000000e+00],
#        [ 1.0000000e+00,  3.5844439e-01, -1.1102230e-16, -1.6911264e-03,
#          0.0000000e+00]], dtype=float32)}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_13439/3187282105.py in <module>
#       7   while not (done or truncated):
#       8     action, _states = model.predict(obs, deterministic=True)
# ----> 9     obs, reward, done,info= vec_env.step(action)
#      10     env.metadata['render_fps'] = 14
#      11     vec_env.render()
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     161         """
#     162         self.step_async(actions)
# --> 163         return self.step_wait()
#     164
#     165     def get_images(self) -> Sequence[np.ndarray]:
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      54         for env_idx in range(self.num_envs):
#      55             obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
# ---> 56                 self.actions[env_idx]
#      57             )
#      58             # convert to SB3 VecEnv api
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/stable_baselines3/common/monitor.py in step(self, action)
#      92         if self.needs_reset:
#      93             raise RuntimeError("Tried to step environment that needs reset")
# ---> 94         observation, reward, terminated, truncated, info = self.env.step(action)
#      95         self.rewards.append(reward)
#      96         if terminated or truncated:
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/gym/wrappers/order_enforcing.py in step(self, action)
#      35         if not self._has_reset:
#      36             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37         return self.env.step(action)
#      38
#      39     def reset(self, **kwargs):
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/gym/wrappers/env_checker.py in step(self, action)
#      37             return env_step_passive_checker(self.env, action)
#      38         else:
# ---> 39             return self.env.step(action)
#      40
#      41     def reset(self, **kwargs):
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/envs/common/abstract.py in step(self, action)
#     225
#     226         self.time += 1 / self.config["policy_frequency"]
# --> 227         self._simulate(action)
#     228
#     229         obs = self.observation_type.observe()
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/envs/common/abstract.py in _simulate(self, action)
#     252             # Ignored if the rendering is done offscreen
#     253             if frame < frames - 1:  # Last frame will be rendered through env.render() as usual
# --> 254                 self._automatic_rendering()
#     255
#     256         self.enable_auto_render = False
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/envs/common/abstract.py in _automatic_rendering(self)
#     308                 self._record_video_wrapper.video_recorder.capture_frame()
#     309             else:
# --> 310                 self.render(self.rendering_mode)
#     311
#     312     def simplify(self) -> 'AbstractEnv':
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/envs/common/abstract.py in render(self, mode)
#     270         self.enable_auto_render = True
#     271
# --> 272         self.viewer.display()
#     273
#     274         if not self.viewer.offscreen:
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/envs/common/graphics.py in display(self)
#      97
#      98         self.sim_surface.move_display_window_to(self.window_position())
# ---> 99         RoadGraphics.display(self.env.road, self.sim_surface)
#     100
#     101         if self.vehicle_trajectory:
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/road/graphics.py in display(road, surface)
#     239             for _to in road.network.graph[_from].keys():
#     240                 for l in road.network.graph[_from][_to]:
# --> 241                     LaneGraphics.display(l, surface)
#     242
#     243     @staticmethod
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/road/graphics.py in display(cls, lane, surface)
#     128         for side in range(2):
#     129             if lane.line_types[side] == LineType.STRIPED:
# --> 130                 cls.striped_line(lane, surface, stripes_count, s0, side)
#     131             elif lane.line_types[side] == LineType.CONTINUOUS:
#     132                 cls.continuous_curve(lane, surface, stripes_count, s0, side)
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/road/graphics.py in striped_line(cls, lane, surface, stripes_count, longitudinal, side)
#     149         ends = longitudinal + np.arange(stripes_count) * cls.STRIPE_SPACING + cls.STRIPE_LENGTH
#     150         lats = [(side - 0.5) * lane.width_at(s) for s in starts]
# --> 151         cls.draw_stripes(lane, surface, starts, ends, lats)
#     152
#     153     @classmethod
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/road/graphics.py in draw_stripes(cls, lane, surface, starts, ends, lats)
#     203                 pygame.draw.line(surface, surface.WHITE,
#     204                                  (surface.vec2pix(lane.position(starts[k], lats[k]))),
# --> 205                                  (surface.vec2pix(lane.position(ends[k], lats[k]))),
#     206                                  max(surface.pix(cls.STRIPE_WIDTH), 1))
#     207
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/road/lane.py in position(self, longitudinal, lateral)
#     177
#     178     def position(self, longitudinal: float, lateral: float) -> np.ndarray:
# --> 179         return self.start + longitudinal * self.direction + lateral * self.direction_lateral
#     180
#     181     def heading_at(self, longitudinal: float) -> float:
#
# KeyboardInterrupt:
