# %%
import gym
import highway_env
from matplotlib import pyplot as plt
# %matplotlib inline


"""for _ in range(3):
    action = env.action_type.actions_indexes["IDLE"]
    obs, reward, done, truncated, info = env.step(action)
    env.metadata['render_fps'] = 14
    env.render()

plt.imshow(env.render(mode="rgb_array"))
plt.show()"""
# Out:
# 'for _ in range(3):\n    action = env.action_type.actions_indexes["IDLE"]\n    obs, reward, done, truncated, info = env.step(action)\n    env.metadata[\'render_fps\'] = 14\n    env.render()\n\nplt.imshow(env.render(mode="rgb_array"))\nplt.show()'

# %%
env1 = gym.make('highway-v0')

env1.configure({"controlled_vehicles": 2})  # Two controlled vehicles
env1.configure({"vehicles_count": 10})  # A single other vehicle, for the sake of visualisation
env1.configure({"collision_reward": 0.2}) 
env1.reset(seed=0)
env1.reset()
# Out:
# /home/santhanam.17/anaconda3/envs/working/lib/python3.7/site-packages/gym/utils/passive_env_checker.py:32: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (5, 5)
#   "A Box observation space has an unconventional shape (neither an image, nor a 1D vector). "
# (array([[ 1.        ,  0.9049861 ,  0.75      ,  0.3125    ,  0.        ],
#         [ 1.        ,  0.09833164, -0.75      , -0.03657916,  0.        ],
#         [ 1.        ,  0.1974102 , -0.25      , -0.03950079,  0.        ],
#         [ 1.        ,  0.3073258 , -0.5       , -0.01320043,  0.        ],
#         [ 1.        ,  0.41827407,  0.        , -0.04373692,  0.        ]],
#        dtype=float32),
#  {'speed': 25,
#   'crashed': False,
#   'action': 3,
#   'rewards': {'collision_reward': 0.0,
#    'right_lane_reward': 1.0,
#    'high_speed_reward': 0.5,
#    'on_road_reward': 1.0}})

# %%
import pprint

pprint.pprint(env.config)

# %%
from stable_baselines3 import DQN
model1 = DQN('MlpPolicy', env1,
              policy_kwargs=dict(net_arch=[256, 256]),
              learning_rate=5e-4,
              buffer_size=15000,
              learning_starts=200,
              batch_size=32,
              gamma=0.8,
              train_freq=1,
              gradient_steps=1,
              target_update_interval=50,
              verbose=1,
              tensorboard_log="highway_dqn/")
model1.learn(int(2e4))
model1.save("highway_dqn/model1")

model1 = DQN.load("highway_dqn/model1", env=env1)
# Out:
# /home/santhanam.17/anaconda3/envs/working/lib/python3.7/site-packages/torch/cuda/__init__.py:88: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# 2022-12-09 17:04:49.887792: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-09 17:04:49.991218: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 2022-12-09 17:04:50.447676: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/santhanam.17/anaconda3/envs/working/lib/python3.7/site-packages/cv2/../../lib64:/home/santhanam.17/Carla_scripts/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2022-12-09 17:04:50.447757: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/santhanam.17/anaconda3/envs/working/lib/python3.7/site-packages/cv2/../../lib64:/home/santhanam.17/Carla_scripts/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2022-12-09 17:04:50.447761: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Logging to highway_dqn/DQN_9
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | -1.58    |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 11       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 15       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 150      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 16       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 251      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.123    |
# |    n_updates        | 50       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 1.91     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 15       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 290      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0611   |
# |    n_updates        | 89       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 2.38     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 14       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 327      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0449   |
# |    n_updates        | 126      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 2.81     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 13       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 398      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 197      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 2.75     |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 13       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 425      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0611   |
# |    n_updates        | 224      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 2.73     |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 13       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 449      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.191    |
# |    n_updates        | 248      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 3.05     |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 12       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 502      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.291    |
# |    n_updates        | 301      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 3.59     |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 12       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 554      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 353      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 3.67     |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 12       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 588      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.223    |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 3.94     |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 12       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 652      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.154    |
# |    n_updates        | 451      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 3.93     |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 686      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.32     |
# |    n_updates        | 485      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 3.98     |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 726      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.346    |
# |    n_updates        | 525      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 4.34     |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 783      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.173    |
# |    n_updates        | 582      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 4.17     |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 817      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.19     |
# |    n_updates        | 616      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 4.11     |
# |    exploration_rate | 0.602    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 11       |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 838      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.185    |
# |    n_updates        | 637      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 4.13     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 11       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 861      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.131    |
# |    n_updates        | 660      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 4.71     |
# |    exploration_rate | 0.553    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 11       |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 942      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.221    |
# |    n_updates        | 741      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 4.69     |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 11       |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 972      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.426    |
# |    n_updates        | 771      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 4.84     |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 11       |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 1016     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.289    |
# |    n_updates        | 815      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 4.78     |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11       |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 1040     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0197   |
# |    n_updates        | 839      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 5.01     |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11       |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 1112     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.306    |
# |    n_updates        | 911      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 4.99     |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11       |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 1148     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0976   |
# |    n_updates        | 947      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 5.05     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 11       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 1181     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.107    |
# |    n_updates        | 980      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 5.25     |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11       |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 1213     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.197    |
# |    n_updates        | 1012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 5.19     |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 11       |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 1239     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.345    |
# |    n_updates        | 1038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 5.8      |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 10       |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 1320     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.286    |
# |    n_updates        | 1119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 5.86     |
# |    exploration_rate | 0.361    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 10       |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 1345     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.275    |
# |    n_updates        | 1144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 5.85     |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 10       |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 1367     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 1166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 5.9      |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 10       |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 1398     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.312    |
# |    n_updates        | 1197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 6.21     |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 10       |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 1456     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.124    |
# |    n_updates        | 1255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 6.3      |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 10       |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 1486     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.218    |
# |    n_updates        | 1285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 6.52     |
# |    exploration_rate | 0.268    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 10       |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 1542     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.322    |
# |    n_updates        | 1341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 6.37     |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 10       |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 1571     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.218    |
# |    n_updates        | 1370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 6.3      |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 10       |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 1585     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.223    |
# |    n_updates        | 1384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.79     |
# |    ep_rew_mean      | 6.37     |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 10       |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 1631     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.112    |
# |    n_updates        | 1430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.67     |
# |    ep_rew_mean      | 6.39     |
# |    exploration_rate | 0.215    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 10       |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 1653     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.192    |
# |    n_updates        | 1452     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.85     |
# |    ep_rew_mean      | 6.68     |
# |    exploration_rate | 0.187    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 10       |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 1711     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.158    |
# |    n_updates        | 1510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 6.66     |
# |    exploration_rate | 0.165    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 10       |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 1758     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0571   |
# |    n_updates        | 1557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.78     |
# |    ep_rew_mean      | 6.89     |
# |    exploration_rate | 0.147    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 10       |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 1795     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.057    |
# |    n_updates        | 1594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.87     |
# |    ep_rew_mean      | 7.03     |
# |    exploration_rate | 0.133    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 10       |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 1825     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 1624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.98     |
# |    ep_rew_mean      | 7.12     |
# |    exploration_rate | 0.117    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 10       |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 1859     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.381    |
# |    n_updates        | 1658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.56     |
# |    ep_rew_mean      | 6.81     |
# |    exploration_rate | 0.0985   |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 10       |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 1898     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.323    |
# |    n_updates        | 1697     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.58     |
# |    ep_rew_mean      | 6.89     |
# |    exploration_rate | 0.0832   |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 10       |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 1930     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0395   |
# |    n_updates        | 1729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 6.82     |
# |    exploration_rate | 0.0685   |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 10       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 1961     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0984   |
# |    n_updates        | 1760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 7.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 10       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 2014     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.509    |
# |    n_updates        | 1813     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72     |
# |    ep_rew_mean      | 7.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 10       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 2084     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.302    |
# |    n_updates        | 1883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 7.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 10       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 2118     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 1917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.86     |
# |    ep_rew_mean      | 7.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 10       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 2167     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.185    |
# |    n_updates        | 1966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 8.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 10       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 2248     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 2047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 10       |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 2288     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.215    |
# |    n_updates        | 2087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 8.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 10       |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 2331     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.329    |
# |    n_updates        | 2130     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 10       |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 2372     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.369    |
# |    n_updates        | 2171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 8.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 10       |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 2405     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.136    |
# |    n_updates        | 2204     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 8.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 10       |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 2420     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.275    |
# |    n_updates        | 2219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 8.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 10       |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 2461     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.136    |
# |    n_updates        | 2260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 8.49     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 10       |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 2519     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.034    |
# |    n_updates        | 2318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 8.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 10       |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 2563     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.133    |
# |    n_updates        | 2362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 10       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 2622     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.276    |
# |    n_updates        | 2421     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 10       |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 2705     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.202    |
# |    n_updates        | 2504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 9.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 10       |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 2744     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.16     |
# |    n_updates        | 2543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 9.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 10       |
# |    time_elapsed     | 276      |
# |    total_timesteps  | 2781     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0458   |
# |    n_updates        | 2580     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 9.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 10       |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 2867     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.133    |
# |    n_updates        | 2666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 9        |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 2919     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.293    |
# |    n_updates        | 2718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 9        |
# |    time_elapsed     | 294      |
# |    total_timesteps  | 2945     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.448    |
# |    n_updates        | 2744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 9        |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 2966     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.365    |
# |    n_updates        | 2765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 9        |
# |    time_elapsed     | 302      |
# |    total_timesteps  | 3006     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.301    |
# |    n_updates        | 2805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 9        |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 3048     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.22     |
# |    n_updates        | 2847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 9        |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 3067     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.532    |
# |    n_updates        | 2866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 9        |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 3108     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.201    |
# |    n_updates        | 2907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 9.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 9        |
# |    time_elapsed     | 322      |
# |    total_timesteps  | 3184     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.229    |
# |    n_updates        | 2983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 9        |
# |    time_elapsed     | 328      |
# |    total_timesteps  | 3232     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.136    |
# |    n_updates        | 3031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 9        |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 3263     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0551   |
# |    n_updates        | 3062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 9.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 9        |
# |    time_elapsed     | 336      |
# |    total_timesteps  | 3298     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.236    |
# |    n_updates        | 3097     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 9        |
# |    time_elapsed     | 343      |
# |    total_timesteps  | 3364     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.219    |
# |    n_updates        | 3163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 9.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 9        |
# |    time_elapsed     | 346      |
# |    total_timesteps  | 3391     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.201    |
# |    n_updates        | 3190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 9        |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 3422     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.334    |
# |    n_updates        | 3221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 9        |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 3464     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.173    |
# |    n_updates        | 3263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 9.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 9        |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 3519     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.309    |
# |    n_updates        | 3318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 9.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 9        |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 3553     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.204    |
# |    n_updates        | 3352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 9.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 9        |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 3575     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.394    |
# |    n_updates        | 3374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 9        |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 3641     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.21     |
# |    n_updates        | 3440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 9.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 9        |
# |    time_elapsed     | 375      |
# |    total_timesteps  | 3671     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 3470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 9        |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 3692     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.109    |
# |    n_updates        | 3491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 8.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 9        |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 3717     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.376    |
# |    n_updates        | 3516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 8.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 9        |
# |    time_elapsed     | 386      |
# |    total_timesteps  | 3764     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 3563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 8.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# ...
# |    learning_rate    | 0.0005   |
# |    loss             | 0.252    |
# |    n_updates        | 17363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 9        |
# |    time_elapsed     | 1949     |
# |    total_timesteps  | 17696    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.076    |
# |    n_updates        | 17495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 9        |
# |    time_elapsed     | 1964     |
# |    total_timesteps  | 17818    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0467   |
# |    n_updates        | 17617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 9        |
# |    time_elapsed     | 1970     |
# |    total_timesteps  | 17866    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0864   |
# |    n_updates        | 17665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 9        |
# |    time_elapsed     | 1983     |
# |    total_timesteps  | 17975    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.306    |
# |    n_updates        | 17774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 9        |
# |    time_elapsed     | 1990     |
# |    total_timesteps  | 18045    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0981   |
# |    n_updates        | 17844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 9        |
# |    time_elapsed     | 2001     |
# |    total_timesteps  | 18135    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.121    |
# |    n_updates        | 17934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 9        |
# |    time_elapsed     | 2011     |
# |    total_timesteps  | 18220    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.142    |
# |    n_updates        | 18019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 9        |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 18271    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0914   |
# |    n_updates        | 18070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 9        |
# |    time_elapsed     | 2029     |
# |    total_timesteps  | 18358    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.134    |
# |    n_updates        | 18157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 9        |
# |    time_elapsed     | 2038     |
# |    total_timesteps  | 18443    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.218    |
# |    n_updates        | 18242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 9        |
# |    time_elapsed     | 2042     |
# |    total_timesteps  | 18482    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0209   |
# |    n_updates        | 18281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 9        |
# |    time_elapsed     | 2047     |
# |    total_timesteps  | 18539    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0739   |
# |    n_updates        | 18338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 9        |
# |    time_elapsed     | 2053     |
# |    total_timesteps  | 18598    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0818   |
# |    n_updates        | 18397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 9        |
# |    time_elapsed     | 2061     |
# |    total_timesteps  | 18669    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.258    |
# |    n_updates        | 18468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 9        |
# |    time_elapsed     | 2066     |
# |    total_timesteps  | 18718    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0675   |
# |    n_updates        | 18517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 9        |
# |    time_elapsed     | 2077     |
# |    total_timesteps  | 18819    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0873   |
# |    n_updates        | 18618    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 9        |
# |    time_elapsed     | 2086     |
# |    total_timesteps  | 18912    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0772   |
# |    n_updates        | 18711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 9        |
# |    time_elapsed     | 2093     |
# |    total_timesteps  | 18980    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.115    |
# |    n_updates        | 18779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 9        |
# |    time_elapsed     | 2098     |
# |    total_timesteps  | 19031    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0696   |
# |    n_updates        | 18830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 9        |
# |    time_elapsed     | 2107     |
# |    total_timesteps  | 19120    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.131    |
# |    n_updates        | 18919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 9        |
# |    time_elapsed     | 2117     |
# |    total_timesteps  | 19201    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.098    |
# |    n_updates        | 19000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 9        |
# |    time_elapsed     | 2127     |
# |    total_timesteps  | 19285    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.076    |
# |    n_updates        | 19084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 9        |
# |    time_elapsed     | 2135     |
# |    total_timesteps  | 19353    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.109    |
# |    n_updates        | 19152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 9        |
# |    time_elapsed     | 2143     |
# |    total_timesteps  | 19414    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0756   |
# |    n_updates        | 19213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 9        |
# |    time_elapsed     | 2155     |
# |    total_timesteps  | 19503    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.266    |
# |    n_updates        | 19302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 9        |
# |    time_elapsed     | 2168     |
# |    total_timesteps  | 19611    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0813   |
# |    n_updates        | 19410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 9        |
# |    time_elapsed     | 2180     |
# |    total_timesteps  | 19708    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.119    |
# |    n_updates        | 19507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 9        |
# |    time_elapsed     | 2190     |
# |    total_timesteps  | 19793    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 19592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 9        |
# |    time_elapsed     | 2205     |
# |    total_timesteps  | 19924    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0764   |
# |    n_updates        | 19723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 9        |
# |    time_elapsed     | 2209     |
# |    total_timesteps  | 19965    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0895   |
# |    n_updates        | 19764    |
# ----------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env2 = gym.make('highway-v0')

env2.configure({"controlled_vehicles": 2})  # Two controlled vehicles
env2.configure({"vehicles_count": 10})  # A single other vehicle, for the sake of visualisation
env2.configure({"collision_reward": 1}) 
env2.reset(seed=0)
env2.reset()
# Out:
# /home/santhanam.17/anaconda3/envs/working/lib/python3.7/site-packages/gym/utils/passive_env_checker.py:32: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (5, 5)
#   "A Box observation space has an unconventional shape (neither an image, nor a 1D vector). "
# (array([[ 1.        ,  0.90415096,  0.5       ,  0.3125    ,  0.        ],
#         [ 1.        ,  0.09771455, -0.5       , -0.02498515,  0.        ],
#         [ 1.        ,  0.20087226,  0.        , -0.02443957,  0.        ],
#         [ 1.        ,  0.30044723,  0.25      , -0.03134198,  0.        ],
#         [ 1.        ,  0.40843213, -0.25      , -0.03672112,  0.        ]],
#        dtype=float32),
#  {'speed': 25,
#   'crashed': False,
#   'action': 3,
#   'rewards': {'collision_reward': 0.0,
#    'right_lane_reward': 0.6666666666666666,
#    'high_speed_reward': 0.5,
#    'on_road_reward': 1.0}})

# %%
model2 = DQN('MlpPolicy', env2,
              policy_kwargs=dict(net_arch=[256, 256]),
              learning_rate=5e-4,
              buffer_size=15000,
              learning_starts=200,
              batch_size=32,
              gamma=0.8,
              train_freq=1,
              gradient_steps=1,
              target_update_interval=50,
              verbose=1,
              tensorboard_log="highway_dqn/")
model2.learn(int(2e4))
model2.save("highway_dqn/model2")

model2 = DQN.load("highway_dqn/model2", env=env2)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_10
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.75     |
# |    ep_rew_mean      | 7.32     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 36       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9        |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 36       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 32       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 144      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 33       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 19       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 292      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0438   |
# |    n_updates        | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 17       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 360      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.226    |
# |    n_updates        | 159      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 15       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 452      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.814    |
# |    n_updates        | 251      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 26.6     |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 14       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 548      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0317   |
# |    n_updates        | 347      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 29.8     |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 14       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 673      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.471    |
# |    n_updates        | 472      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 28.8     |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 13       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 727      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.061    |
# |    n_updates        | 526      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 13       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 761      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.255    |
# |    n_updates        | 560      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 13       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 846      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.688    |
# |    n_updates        | 645      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 30.7     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 12       |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 980      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0412   |
# |    n_updates        | 779      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 12       |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 1104     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.268    |
# |    n_updates        | 903      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11       |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 1264     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.56     |
# |    n_updates        | 1063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 37.5     |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 1398     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0243   |
# |    n_updates        | 1197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 39.8     |
# |    exploration_rate | 0.26     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 11       |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 1558     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.502    |
# |    n_updates        | 1357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 40.9     |
# |    exploration_rate | 0.202    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 10       |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 1681     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0104   |
# |    n_updates        | 1480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.131    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 10       |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 1829     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.289    |
# |    n_updates        | 1628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 43.5     |
# |    exploration_rate | 0.069    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 10       |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 1960     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00998  |
# |    n_updates        | 1759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.2     |
# |    ep_rew_mean      | 45.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 10       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 2120     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.554    |
# |    n_updates        | 1919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 46.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 10       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 2280     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0206   |
# |    n_updates        | 2079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 47.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 10       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 2431     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.26     |
# |    n_updates        | 2230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.6     |
# |    ep_rew_mean      | 48.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 10       |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 2550     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0108   |
# |    n_updates        | 2349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.8     |
# |    ep_rew_mean      | 48.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 10       |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 2682     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0107   |
# |    n_updates        | 2481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.2     |
# |    ep_rew_mean      | 51.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 10       |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 2842     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.281    |
# |    n_updates        | 2641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | 53.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 10       |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 2966     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0125   |
# |    n_updates        | 2765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 54.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 10       |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 3094     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.221    |
# |    n_updates        | 2893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.4     |
# |    ep_rew_mean      | 56.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 10       |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 3234     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.23     |
# |    n_updates        | 3033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31       |
# |    ep_rew_mean      | 58.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 10       |
# |    time_elapsed     | 323      |
# |    total_timesteps  | 3394     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00559  |
# |    n_updates        | 3193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | 60.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 10       |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 3536     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00899  |
# |    n_updates        | 3335     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.2     |
# |    ep_rew_mean      | 61.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 10       |
# |    time_elapsed     | 350      |
# |    total_timesteps  | 3674     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00541  |
# |    n_updates        | 3473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.7     |
# |    ep_rew_mean      | 62.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 10       |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 3822     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.49     |
# |    n_updates        | 3621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | 63.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 10       |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 3982     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00242  |
# |    n_updates        | 3781     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.1     |
# |    ep_rew_mean      | 66       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 10       |
# |    time_elapsed     | 395      |
# |    total_timesteps  | 4142     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00764  |
# |    n_updates        | 3941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.4     |
# |    ep_rew_mean      | 68.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 10       |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 4302     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00726  |
# |    n_updates        | 4101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | 70.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 10       |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 4462     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.271    |
# |    n_updates        | 4261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | 70.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 10       |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 4599     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00973  |
# |    n_updates        | 4398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.3     |
# |    ep_rew_mean      | 70.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 10       |
# |    time_elapsed     | 454      |
# |    total_timesteps  | 4731     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0065   |
# |    n_updates        | 4530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36       |
# |    ep_rew_mean      | 70.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 10       |
# |    time_elapsed     | 466      |
# |    total_timesteps  | 4863     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.509    |
# |    n_updates        | 4662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.1     |
# |    ep_rew_mean      | 70.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 10       |
# |    time_elapsed     | 480      |
# |    total_timesteps  | 5004     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00199  |
# |    n_updates        | 4803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.8     |
# |    ep_rew_mean      | 70       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 10       |
# |    time_elapsed     | 494      |
# |    total_timesteps  | 5137     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.013    |
# |    n_updates        | 4936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | 70.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 10       |
# |    time_elapsed     | 514      |
# |    total_timesteps  | 5297     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00497  |
# |    n_updates        | 5096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | 70.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 10       |
# |    time_elapsed     | 532      |
# |    total_timesteps  | 5447     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00855  |
# |    n_updates        | 5246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.5     |
# |    ep_rew_mean      | 71.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 10       |
# |    time_elapsed     | 551      |
# |    total_timesteps  | 5607     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.016    |
# |    n_updates        | 5406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.5     |
# |    ep_rew_mean      | 71.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 10       |
# |    time_elapsed     | 570      |
# |    total_timesteps  | 5767     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0408   |
# |    n_updates        | 5566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.5     |
# |    ep_rew_mean      | 71.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 10       |
# |    time_elapsed     | 585      |
# |    total_timesteps  | 5927     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.51     |
# |    n_updates        | 5726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.4     |
# |    ep_rew_mean      | 71.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 10       |
# |    time_elapsed     | 599      |
# |    total_timesteps  | 6075     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00482  |
# |    n_updates        | 5874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.7     |
# |    ep_rew_mean      | 71.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 10       |
# |    time_elapsed     | 613      |
# |    total_timesteps  | 6217     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00917  |
# |    n_updates        | 6016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.7     |
# |    ep_rew_mean      | 71.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 10       |
# |    time_elapsed     | 626      |
# |    total_timesteps  | 6353     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00686  |
# |    n_updates        | 6152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.6     |
# |    ep_rew_mean      | 71.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 10       |
# |    time_elapsed     | 640      |
# |    total_timesteps  | 6500     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00388  |
# |    n_updates        | 6299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 72.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 10       |
# |    time_elapsed     | 656      |
# |    total_timesteps  | 6660     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.013    |
# |    n_updates        | 6459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 72.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 10       |
# |    time_elapsed     | 669      |
# |    total_timesteps  | 6788     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.523    |
# |    n_updates        | 6587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.7     |
# |    ep_rew_mean      | 71.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 10       |
# |    time_elapsed     | 680      |
# |    total_timesteps  | 6905     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.294    |
# |    n_updates        | 6704     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.7     |
# |    ep_rew_mean      | 72       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 10       |
# |    time_elapsed     | 695      |
# |    total_timesteps  | 7065     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0119   |
# |    n_updates        | 6864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 72.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 10       |
# |    time_elapsed     | 711      |
# |    total_timesteps  | 7225     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0101   |
# |    n_updates        | 7024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 72.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 10       |
# |    time_elapsed     | 726      |
# |    total_timesteps  | 7385     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00623  |
# |    n_updates        | 7184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 73       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 10       |
# |    time_elapsed     | 742      |
# |    total_timesteps  | 7545     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.505    |
# |    n_updates        | 7344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 72.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 10       |
# |    time_elapsed     | 758      |
# |    total_timesteps  | 7700     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00487  |
# |    n_updates        | 7499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 72.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 10       |
# |    time_elapsed     | 773      |
# |    total_timesteps  | 7849     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.272    |
# |    n_updates        | 7648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 72.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 10       |
# |    time_elapsed     | 788      |
# |    total_timesteps  | 8009     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00366  |
# |    n_updates        | 7808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 72.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 10       |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 8150     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00546  |
# |    n_updates        | 7949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 72.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 10       |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 8286     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.01     |
# |    n_updates        | 8085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 72.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 10       |
# |    time_elapsed     | 830      |
# |    total_timesteps  | 8444     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0162   |
# |    n_updates        | 8243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 72.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 10       |
# |    time_elapsed     | 843      |
# |    total_timesteps  | 8576     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0111   |
# |    n_updates        | 8375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.3     |
# |    ep_rew_mean      | 73.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 10       |
# |    time_elapsed     | 858      |
# |    total_timesteps  | 8736     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0041   |
# |    n_updates        | 8535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.6     |
# |    ep_rew_mean      | 73.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 10       |
# |    time_elapsed     | 874      |
# |    total_timesteps  | 8896     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00414  |
# |    n_updates        | 8695     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.6     |
# |    ep_rew_mean      | 73.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 10       |
# |    time_elapsed     | 890      |
# |    total_timesteps  | 9056     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00391  |
# |    n_updates        | 8855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.7     |
# |    ep_rew_mean      | 74.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 10       |
# |    time_elapsed     | 907      |
# |    total_timesteps  | 9216     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.229    |
# |    n_updates        | 9015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 73.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 10       |
# |    time_elapsed     | 919      |
# |    total_timesteps  | 9324     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00695  |
# |    n_updates        | 9123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 73.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 10       |
# |    time_elapsed     | 937      |
# |    total_timesteps  | 9484     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00615  |
# |    n_updates        | 9283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 73.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 10       |
# |    time_elapsed     | 956      |
# |    total_timesteps  | 9644     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.274    |
# |    n_updates        | 9443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 72.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 10       |
# |    time_elapsed     | 973      |
# |    total_timesteps  | 9781     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00465  |
# |    n_updates        | 9580     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 73.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 10       |
# |    time_elapsed     | 990      |
# |    total_timesteps  | 9941     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.237    |
# |    n_updates        | 9740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.5     |
# |    ep_rew_mean      | 73.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 10       |
# |    time_elapsed     | 1008     |
# |    total_timesteps  | 10101    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.491    |
# |    n_updates        | 9900     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.6     |
# |    ep_rew_mean      | 74.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 10       |
# |    time_elapsed     | 1025     |
# |    total_timesteps  | 10261    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0214   |
# |    n_updates        | 10060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | 73.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 9        |
# |    time_elapsed     | 1042     |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.26     |
# |    n_updates        | 10199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.7     |
# |    ep_rew_mean      | 74.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 9        |
# |    time_elapsed     | 1060     |
# |    total_timesteps  | 10560    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.532    |
# |    n_updates        | 10359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.1     |
# |    ep_rew_mean      | 75.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 9        |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 10720    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00221  |
# |    n_updates        | 10519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.6     |
# |    ep_rew_mean      | 74.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 9        |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 10827    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.274    |
# |    n_updates        | 10626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | 73.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 9        |
# |    time_elapsed     | 1104     |
# |    total_timesteps  | 10961    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.017    |
# |    n_updates        | 10760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | 73.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 9        |
# |    time_elapsed     | 1123     |
# |    total_timesteps  | 11121    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0124   |
# |    n_updates        | 10920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | 73.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 9        |
# |    time_elapsed     | 1140     |
# |    total_timesteps  | 11281    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0022   |
# |    n_updates        | 11080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | 73.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 9        |
# |    time_elapsed     | 1157     |
# |    total_timesteps  | 11441    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.241    |
# |    n_updates        | 11240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.5     |
# |    ep_rew_mean      | 73.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 9        |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 11601    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00699  |
# |    n_updates        | 11400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.5     |
# |    ep_rew_mean      | 73.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 9        |
# |    time_elapsed     | 1191     |
# |    total_timesteps  | 11761    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.211    |
# |    n_updates        | 11560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.5     |
# |    ep_rew_mean      | 73.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 9        |
# |    time_elapsed     | 1205     |
# |    total_timesteps  | 11897    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00255  |
# |    n_updates        | 11696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.6     |
# |    ep_rew_mean      | 74.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 9        |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 12045    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00748  |
# |    n_updates        | 11844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.3     |
# |    ep_rew_mean      | 73.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 9        |
# |    time_elapsed     | 1237     |
# |    total_timesteps  | 12178    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.24     |
# |    n_updates        | 11977    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.5     |
# |    ep_rew_mean      | 73.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 9        |
# |    time_elapsed     | 1253     |
# |    total_timesteps  | 12326    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00444  |
# |    n_updates        | 12125    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 73.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 9        |
# |    time_elapsed     | 1267     |
# |    total_timesteps  | 12458    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00535  |
# |    n_updates        | 12257    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 73.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 9        |
# |    time_elapsed     | 1285     |
# |    total_timesteps  | 12618    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.025    |
# |    n_updates        | 12417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# ...
# |    learning_rate    | 0.0005   |
# |    loss             | 0.298    |
# |    n_updates        | 15311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.8     |
# |    ep_rew_mean      | 74.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 9        |
# |    time_elapsed     | 1602     |
# |    total_timesteps  | 15672    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00571  |
# |    n_updates        | 15471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.9     |
# |    ep_rew_mean      | 74.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 9        |
# |    time_elapsed     | 1618     |
# |    total_timesteps  | 15832    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.012    |
# |    n_updates        | 15631    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.9     |
# |    ep_rew_mean      | 74.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 9        |
# |    time_elapsed     | 1633     |
# |    total_timesteps  | 15971    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00303  |
# |    n_updates        | 15770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38       |
# |    ep_rew_mean      | 75       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 9        |
# |    time_elapsed     | 1649     |
# |    total_timesteps  | 16131    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0067   |
# |    n_updates        | 15930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.3     |
# |    ep_rew_mean      | 75.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 9        |
# |    time_elapsed     | 1665     |
# |    total_timesteps  | 16291    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.253    |
# |    n_updates        | 16090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38       |
# |    ep_rew_mean      | 74.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 9        |
# |    time_elapsed     | 1677     |
# |    total_timesteps  | 16416    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00667  |
# |    n_updates        | 16215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38       |
# |    ep_rew_mean      | 74.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 9        |
# |    time_elapsed     | 1690     |
# |    total_timesteps  | 16549    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0031   |
# |    n_updates        | 16348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.8     |
# |    ep_rew_mean      | 74.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 9        |
# |    time_elapsed     | 1702     |
# |    total_timesteps  | 16682    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00365  |
# |    n_updates        | 16481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.5     |
# |    ep_rew_mean      | 74       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 9        |
# |    time_elapsed     | 1715     |
# |    total_timesteps  | 16814    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0105   |
# |    n_updates        | 16613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.3     |
# |    ep_rew_mean      | 73.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 9        |
# |    time_elapsed     | 1729     |
# |    total_timesteps  | 16948    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.004    |
# |    n_updates        | 16747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 73.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 9        |
# |    time_elapsed     | 1743     |
# |    total_timesteps  | 17077    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00265  |
# |    n_updates        | 16876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | 72.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 9        |
# |    time_elapsed     | 1756     |
# |    total_timesteps  | 17214    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.022    |
# |    n_updates        | 17013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 73.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 9        |
# |    time_elapsed     | 1775     |
# |    total_timesteps  | 17374    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00731  |
# |    n_updates        | 17173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | 73       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 9        |
# |    time_elapsed     | 1790     |
# |    total_timesteps  | 17505    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00501  |
# |    n_updates        | 17304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | 73       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 9        |
# |    time_elapsed     | 1807     |
# |    total_timesteps  | 17665    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.162    |
# |    n_updates        | 17464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 73.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 9        |
# |    time_elapsed     | 1823     |
# |    total_timesteps  | 17825    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0132   |
# |    n_updates        | 17624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.3     |
# |    ep_rew_mean      | 73.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 9        |
# |    time_elapsed     | 1838     |
# |    total_timesteps  | 17985    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00461  |
# |    n_updates        | 17784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | 73       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 9        |
# |    time_elapsed     | 1851     |
# |    total_timesteps  | 18118    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00251  |
# |    n_updates        | 17917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 72.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 9        |
# |    time_elapsed     | 1865     |
# |    total_timesteps  | 18260    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00753  |
# |    n_updates        | 18059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 72.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 9        |
# |    time_elapsed     | 1881     |
# |    total_timesteps  | 18420    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.287    |
# |    n_updates        | 18219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 72.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 9        |
# |    time_elapsed     | 1896     |
# |    total_timesteps  | 18580    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00179  |
# |    n_updates        | 18379    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.7     |
# |    ep_rew_mean      | 72.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 9        |
# |    time_elapsed     | 1910     |
# |    total_timesteps  | 18723    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00108  |
# |    n_updates        | 18522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 72.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 9        |
# |    time_elapsed     | 1925     |
# |    total_timesteps  | 18883    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00926  |
# |    n_updates        | 18682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.6     |
# |    ep_rew_mean      | 72.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 9        |
# |    time_elapsed     | 1940     |
# |    total_timesteps  | 19009    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00544  |
# |    n_updates        | 18808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.6     |
# |    ep_rew_mean      | 72.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 9        |
# |    time_elapsed     | 1958     |
# |    total_timesteps  | 19169    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00499  |
# |    n_updates        | 18968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.5     |
# |    ep_rew_mean      | 72.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 9        |
# |    time_elapsed     | 1976     |
# |    total_timesteps  | 19324    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.153    |
# |    n_updates        | 19123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36       |
# |    ep_rew_mean      | 71       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 9        |
# |    time_elapsed     | 1991     |
# |    total_timesteps  | 19434    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0147   |
# |    n_updates        | 19233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.1     |
# |    ep_rew_mean      | 71.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 9        |
# |    time_elapsed     | 2008     |
# |    total_timesteps  | 19582    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00217  |
# |    n_updates        | 19381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.9     |
# |    ep_rew_mean      | 70.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 9        |
# |    time_elapsed     | 2022     |
# |    total_timesteps  | 19721    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00216  |
# |    n_updates        | 19520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.5     |
# |    ep_rew_mean      | 70       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 9        |
# |    time_elapsed     | 2033     |
# |    total_timesteps  | 19844    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0122   |
# |    n_updates        | 19643    |
# ----------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env3 = gym.make('highway-v0')

env3.configure({"controlled_vehicles": 2})  # Two controlled vehicles
env3.configure({"vehicles_count": 10})  # A single other vehicle, for the sake of visualisation
env3.configure({"collision_reward": 0.5}) 
env3.configure({
  "action": {
    "type": "MultiAgentAction",
    "action_config": {
      "type": "DiscreteMetaAction",
    }
  }
})
env3.reset()

"""
_, (ax1, ax2) = plt.subplots(nrows=2)
ax1.imshow(env2.render(mode="rgb_array"))
ax1.set_title("Initial state")

# Make the first vehicle change to the left lane, and the second one to the right
action_1, action_2 = 0, 2  # See highway_env.envs.common.action.DiscreteMetaAction.ACTIONS_ALL
env2.step((action_1, action_2))

ax2.imshow(env2.render(mode="rgb_array"))
ax2.set_title("After sending actions to each vehicle")
plt.show()"""
# Out:
# '\n_, (ax1, ax2) = plt.subplots(nrows=2)\nax1.imshow(env2.render(mode="rgb_array"))\nax1.set_title("Initial state")\n\n# Make the first vehicle change to the left lane, and the second one to the right\naction_1, action_2 = 0, 2  # See highway_env.envs.common.action.DiscreteMetaAction.ACTIONS_ALL\nenv2.step((action_1, action_2))\n\nax2.imshow(env2.render(mode="rgb_array"))\nax2.set_title("After sending actions to each vehicle")\nplt.show()'

# %%
from stable_baselines3 import DQN

model1 = DQN.load("highway_dqn/model1",env=env1)
model2 = DQN.load("highway_dqn/model2",env=env2)
while True:
  vec_env1=model1.get_env()
  done = truncated = False
  obs1 = vec_env1.reset()

  vec_env2=model2.get_env()
  done = truncated = False
  obs2 = vec_env2.reset()

  #print(info)
  while not (done or truncated):
    action1, _states1 = model1.predict(obs1, deterministic=True)
    action2, _states2 = model2.predict(obs2, deterministic=True)

    env3.metadata['render_fps'] = 14
    env3.step((action1[0], action2[0]))
    env3.render()


    
    """_, (ax1, ax2) = plt.subplots(nrows=2)
    ax1.imshow(env3.render(mode="rgb_array"))
    ax1.set_title("Initial state")
    print(action1,action2)
    # Make the first vehicle change to the left lane, and the second one to the right
    #action_1, action_2 = 0, 2  # See highway_env.envs.common.action.DiscreteMetaAction.ACTIONS_ALL
    env3.step((action1[0], action2[0]))

    ax2.imshow(env3.render(mode="rgb_array"))
    ax2.set_title("After sending actions to each vehicle")
    plt.show()"""
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/santhanam.17/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/utils.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return y[0] + (v - x[0]) * (y[1] - y[0]) / (x[1] - x[0])
# /home/santhanam.17/anaconda3/envs/working/lib/python3.7/site-packages/gym/utils/passive_env_checker.py:259: UserWarning: WARN: The reward is an inf value.
#   logger.warn("The reward is an inf value.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18037/3653161381.py in <module>
#      18
#      19     env3.metadata['render_fps'] = 14
# ---> 20     env3.step((action1[0], action2[0]))
#      21     env3.render()
#      22
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/gym/wrappers/order_enforcing.py in step(self, action)
#      35         if not self._has_reset:
#      36             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37         return self.env.step(action)
#      38
#      39     def reset(self, **kwargs):
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/gym/wrappers/env_checker.py in step(self, action)
#      37             return env_step_passive_checker(self.env, action)
#      38         else:
# ---> 39             return self.env.step(action)
#      40
#      41     def reset(self, **kwargs):
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/envs/common/abstract.py in step(self, action)
#     225
#     226         self.time += 1 / self.config["policy_frequency"]
# --> 227         self._simulate(action)
#     228
#     229         obs = self.observation_type.observe()
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/envs/common/abstract.py in _simulate(self, action)
#     246
#     247             self.road.act()
# --> 248             self.road.step(1 / self.config["simulation_frequency"])
#     249             self.steps += 1
#     250
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/road/road.py in step(self, dt)
#     331         """
#     332         for vehicle in self.vehicles:
# --> 333             vehicle.step(dt)
#     334         for i, vehicle in enumerate(self.vehicles):
#     335             for other in self.vehicles[i+1:]:
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/vehicle/behavior.py in step(self, dt)
#     122         """
#     123         self.timer += dt
# --> 124         super().step(dt)
#     125
#     126     def acceleration(self,
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/vehicle/kinematics.py in step(self, dt)
#     131         self.heading += self.speed * np.sin(beta) / (self.LENGTH / 2) * dt
#     132         self.speed += self.action['acceleration'] * dt
# --> 133         self.on_state_update()
#     134
#     135     def clip_actions(self) -> None:
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/vehicle/kinematics.py in on_state_update(self)
#     146     def on_state_update(self) -> None:
#     147         if self.road:
# --> 148             self.lane_index = self.road.network.get_closest_lane_index(self.position, self.heading)
#     149             self.lane = self.road.network.get_lane(self.lane_index)
#     150             if self.road.record_history:
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/road/road.py in get_closest_lane_index(self, position, heading)
#      59             for _to, lanes in to_dict.items():
#      60                 for _id, l in enumerate(lanes):
# ---> 61                     distances.append(l.distance_with_heading(position, heading))
#      62                     indexes.append((_from, _to, _id))
#      63         return indexes[int(np.argmin(distances))]
#
# ~/anaconda3/envs/working/lib/python3.7/site-packages/highway_env/road/lane.py in distance_with_heading(self, position, heading, heading_weight)
#     124             return self.distance(position)
#     125         s, r = self.local_coordinates(position)
# --> 126         angle = np.abs(self.local_angle(heading, s))
#     127         return abs(r) + max(s - self.length, 0) + max(0 - s, 0) + heading_weight*angle
#     128
#
# KeyboardInterrupt:
